# %% [markdown]
# # <font color='blue'>**LABORATORIO 2.**
#
# <font color='red'>Integrantes:
#
#
# * Daniel Velasco Rodriguez 2215456
# * Ruben Dario Fierro 2215789

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %% [markdown]
# ### Import libs

# %%
from __future__ import division
from __future__ import print_function
from __future__ import absolute_import
import random
import pprint
import sys
import time
import numpy as np
from optparse import OptionParser
import pickle
import math
import cv2
import copy
from matplotlib import pyplot as plt
import tensorflow as tf
import pandas as pd
import os

from sklearn.metrics import average_precision_score

from keras import backend as K
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from keras.layers import Flatten, Dense, Input, Conv2D, MaxPooling2D, Dropout
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, TimeDistributed
from keras.utils.layer_utils import get_source_inputs
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.losses import categorical_crossentropy

from keras.models import Model
from keras.utils import generic_utils
from keras.engine.base_layer import Layer, InputSpec
from keras import initializers, regularizers

# %% [markdown]
# #### Config setting

# %%
class Config:

	def __init__(self):

		# Print the process or not
		self.verbose = True

		# Name of base network
		self.network = 'vgg'

		# Setting for data augmentation
		self.use_horizontal_flips = False
		self.use_vertical_flips = False
		self.rot_90 = False

		# Anchor box scales
    # Note that if im_size is smaller, anchor_box_scales should be scaled
    # Original anchor_box_scales in the paper is [128, 256, 512]
		self.anchor_box_scales = [64, 128, 256] 

		# Anchor box ratios
		self.anchor_box_ratios = [[1, 1], [1./math.sqrt(2), 2./math.sqrt(2)], [2./math.sqrt(2), 1./math.sqrt(2)]]

		# Size to resize the smallest side of the image
		# Original setting in paper is 600. Set to 300 in here to save training time
		self.im_size = 300

		# image channel-wise mean to subtract
		self.img_channel_mean = [103.939, 116.779, 123.68]
		self.img_scaling_factor = 1.0

		# number of ROIs at once
		self.num_rois = 4

		# stride at the RPN (this depends on the network configuration)
		self.rpn_stride = 16

		self.balanced_classes = False

		# scaling the stdev
		self.std_scaling = 4.0
		self.classifier_regr_std = [8.0, 8.0, 4.0, 4.0]

		# overlaps for RPN
		self.rpn_min_overlap = 0.3
		self.rpn_max_overlap = 0.7

		# overlaps for classifier ROIs
		self.classifier_min_overlap = 0.1
		self.classifier_max_overlap = 0.5

		# placeholder for the class mapping, automatically generated by the parser
		self.class_mapping = None

		self.model_path = None

# %% [markdown]
# #### Parser the data from annotation file

# %%
def get_data(input_path):
	"""Parser the data from annotation file
	
	Args:
		input_path: annotation file path

	Returns:
		all_data: list(filepath, width, height, list(bboxes))
		classes_count: dict{key:class_name, value:count_num} 
			e.g. {'Car': 2383, 'Mobile phone': 1108, 'Person': 3745}
		class_mapping: dict{key:class_name, value: idx}
			e.g. {'Car': 0, 'Mobile phone': 1, 'Person': 2}
	"""
	found_bg = False
	all_imgs = {}

	classes_count = {}

	class_mapping = {}

	visualise = True

	i = 1
	
	with open(input_path,'r') as f:

		print('Parsing annotation files')

		for line in f:

			# Print process
			sys.stdout.write('\r'+'idx=' + str(i))
			i += 1

			line_split = line.strip().split(',')

			# Make sure the info saved in annotation file matching the format (path_filename, x1, y1, x2, y2, class_name)
			# Note:
			#	One path_filename might has several classes (class_name)
			#	x1, y1, x2, y2 are the pixel value of the origial image, not the ratio value
			#	(x1, y1) top left coordinates; (x2, y2) bottom right coordinates
			#   x1,y1-------------------
			#	|						|
			#	|						|
			#	|						|
			#	|						|
			#	---------------------x2,y2

			(filename,x1,y1,x2,y2,class_name) = line_split

			if class_name not in classes_count:
				classes_count[class_name] = 1
			else:
				classes_count[class_name] += 1

			if class_name not in class_mapping:
				if class_name == 'bg' and found_bg == False:
					print('Found class name with special name bg. Will be treated as a background region (this is usually for hard negative mining).')
					found_bg = True
				class_mapping[class_name] = len(class_mapping)

			if filename not in all_imgs:
				all_imgs[filename] = {}
				
				img = cv2.imread(filename)
				(rows,cols) = img.shape[:2]
				all_imgs[filename]['filepath'] = filename
				all_imgs[filename]['width'] = cols
				all_imgs[filename]['height'] = rows
				all_imgs[filename]['bboxes'] = []
				# if np.random.randint(0,6) > 0:
				# 	all_imgs[filename]['imageset'] = 'trainval'
				# else:
				# 	all_imgs[filename]['imageset'] = 'test'

			all_imgs[filename]['bboxes'].append({'class': class_name, 'x1': int(x1), 'x2': int(x2), 'y1': int(y1), 'y2': int(y2)})


		all_data = []
		for key in all_imgs:
			all_data.append(all_imgs[key])
		
		# make sure the bg class is last in the list
		if found_bg:
			if class_mapping['bg'] != len(class_mapping) - 1:
				key_to_switch = [key for key in class_mapping.keys() if class_mapping[key] == len(class_mapping)-1][0]
				val_to_switch = class_mapping['bg']
				class_mapping['bg'] = len(class_mapping) - 1
				class_mapping[key_to_switch] = val_to_switch
		
		return all_data, classes_count, class_mapping

# %% [markdown]
# #### Define ROI Pooling Convolutional Layer

# %%
class RoiPoolingConv(Layer):
    '''ROI pooling layer for 2D inputs.
    See Spatial Pyramid Pooling in Deep Convolutional Networks for Visual Recognition,
    K. He, X. Zhang, S. Ren, J. Sun
    # Arguments
        pool_size: int
            Size of pooling region to use. pool_size = 7 will result in a 7x7 region.
        num_rois: number of regions of interest to be used
    # Input shape
        list of two 4D tensors [X_img,X_roi] with shape:
        X_img:
        `(1, rows, cols, channels)`
        X_roi:
        `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
    # Output shape
        3D tensor with shape:
        `(1, num_rois, channels, pool_size, pool_size)`
    '''
    def __init__(self, pool_size, num_rois, **kwargs):

        #self.dim_ordering = K.image_dim_ordering()
        self.dim_ordering = K.image_data_format()
        self.pool_size = pool_size
        self.num_rois = num_rois

        super(RoiPoolingConv, self).__init__(**kwargs)

    def build(self, input_shape):
        self.nb_channels = input_shape[0][3]   

    def compute_output_shape(self, input_shape):
        return None, self.num_rois, self.pool_size, self.pool_size, self.nb_channels

    def call(self, x, mask=None):

        assert(len(x) == 2)

        # x[0] is image with shape (rows, cols, channels)
        img = x[0]

        # x[1] is roi with shape (num_rois,4) with ordering (x,y,w,h)
        rois = x[1]

        input_shape = K.shape(img)

        outputs = []

        for roi_idx in range(self.num_rois):

            x = rois[0, roi_idx, 0]
            y = rois[0, roi_idx, 1]
            w = rois[0, roi_idx, 2]
            h = rois[0, roi_idx, 3]

            x = K.cast(x, 'int32')
            y = K.cast(y, 'int32')
            w = K.cast(w, 'int32')
            h = K.cast(h, 'int32')

            # Resized roi of the image to pooling size (7x7)
            rs = tf.image.resize(img[:, y:y+h, x:x+w, :], (self.pool_size, self.pool_size))
            outputs.append(rs)
                

        final_output = K.concatenate(outputs, axis=0)

        # Reshape to (1, num_rois, pool_size, pool_size, nb_channels)
        # Might be (1, 4, 7, 7, 3)
        final_output = K.reshape(final_output, (1, self.num_rois, self.pool_size, self.pool_size, self.nb_channels))

        # permute_dimensions is similar to transpose
        final_output = K.permute_dimensions(final_output, (0, 1, 2, 3, 4))

        return final_output
    
    
    def get_config(self):
        config = {'pool_size': self.pool_size,
                  'num_rois': self.num_rois}
        base_config = super(RoiPoolingConv, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# #### Vgg-16 model

# %%
def get_img_output_length(width, height):
    def get_output_length(input_length):
        return input_length//16

    return get_output_length(width), get_output_length(height)    

def nn_base(input_tensor=None, trainable=False):


    input_shape = (None, None, 3)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    bn_axis = 3

    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(img_input)
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    # x = MaxPooling2D((2, 2), strides=(2, 2), name='block5_pool')(x)

    return x

# %% [markdown]
# ####  RPN layer

# %%
def rpn_layer(base_layers, num_anchors):
    """Create a rpn layer
        Step1: Pass through the feature map from base layer to a 3x3 512 channels convolutional layer
                Keep the padding 'same' to preserve the feature map's size
        Step2: Pass the step1 to two (1,1) convolutional layer to replace the fully connected layer
                classification layer: num_anchors (9 in here) channels for 0, 1 sigmoid activation output
                regression layer: num_anchors*4 (36 in here) channels for computing the regression of bboxes with linear activation
    Args:
        base_layers: vgg in here
        num_anchors: 9 in here

    Returns:
        [x_class, x_regr, base_layers]
        x_class: classification for whether it's an object
        x_regr: bboxes regression
        base_layers: vgg in here
    """
    x = Conv2D(512, (3, 3), padding='same', activation='relu', kernel_initializer='normal', name='rpn_conv1')(base_layers)

    x_class = Conv2D(num_anchors, (1, 1), activation='sigmoid', kernel_initializer='uniform', name='rpn_out_class')(x)
    x_regr = Conv2D(num_anchors * 4, (1, 1), activation='linear', kernel_initializer='zero', name='rpn_out_regress')(x)

    return [x_class, x_regr, base_layers]

# %% [markdown]
# ####  Classifier layer

# %%
def classifier_layer(base_layers, input_rois, num_rois, nb_classes = 4):
    """Create a classifier layer
    
    Args:
        base_layers: vgg
        input_rois: `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
        num_rois: number of rois to be processed in one time (4 in here)

    Returns:
        list(out_class, out_regr)
        out_class: classifier layer output
        out_regr: regression layer output
    """

    input_shape = (num_rois,7,7,512)

    pooling_regions = 7

    # out_roi_pool.shape = (1, num_rois, channels, pool_size, pool_size)
    # num_rois (4) 7x7 roi pooling
    out_roi_pool = RoiPoolingConv(pooling_regions, num_rois)([base_layers, input_rois])

    # Flatten the convlutional layer and connected to 2 FC and 2 dropout
    out = TimeDistributed(Flatten(name='flatten'))(out_roi_pool)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc1'))(out)
    out = TimeDistributed(Dropout(0.5))(out)
    out = TimeDistributed(Dense(4096, activation='relu', name='fc2'))(out)
    out = TimeDistributed(Dropout(0.5))(out)

    # There are two output layer
    # out_class: softmax acivation function for classify the class name of the object
    # out_regr: linear activation function for bboxes coordinates regression
    out_class = TimeDistributed(Dense(nb_classes, activation='softmax', kernel_initializer='zero'), name='dense_class_{}'.format(nb_classes))(out)
    # note: no regression target for bg class
    out_regr = TimeDistributed(Dense(4 * (nb_classes-1), activation='linear', kernel_initializer='zero'), name='dense_regress_{}'.format(nb_classes))(out)

    return [out_class, out_regr]

# %% [markdown]
# #### Calculate IoU (Intersection of Union)

# %%
def union(au, bu, area_intersection):
	area_a = (au[2] - au[0]) * (au[3] - au[1])
	area_b = (bu[2] - bu[0]) * (bu[3] - bu[1])
	area_union = area_a + area_b - area_intersection
	return area_union


def intersection(ai, bi):
	x = max(ai[0], bi[0])
	y = max(ai[1], bi[1])
	w = min(ai[2], bi[2]) - x
	h = min(ai[3], bi[3]) - y
	if w < 0 or h < 0:
		return 0
	return w*h


def iou(a, b):
	# a and b should be (x1,y1,x2,y2)

	if a[0] >= a[2] or a[1] >= a[3] or b[0] >= b[2] or b[1] >= b[3]:
		return 0.0

	area_i = intersection(a, b)
	area_u = union(a, b, area_i)

	return float(area_i) / float(area_u + 1e-6)

# %% [markdown]
# #### Calculate the rpn for all anchors of all images

# %%
def calc_rpn(C, img_data, width, height, resized_width, resized_height, img_length_calc_function):
	"""(Important part!) Calculate the rpn for all anchors 
		If feature map has shape 38x50=1900, there are 1900x9=17100 potential anchors
	
	Args:
		C: config
		img_data: augmented image data
		width: original image width (e.g. 600)
		height: original image height (e.g. 800)
		resized_width: resized image width according to C.im_size (e.g. 300)
		resized_height: resized image height according to C.im_size (e.g. 400)
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size

	Returns:
		y_rpn_cls: list(num_bboxes, y_is_box_valid + y_rpn_overlap)
			y_is_box_valid: 0 or 1 (0 means the box is invalid, 1 means the box is valid)
			y_rpn_overlap: 0 or 1 (0 means the box is not an object, 1 means the box is an object)
		y_rpn_regr: list(num_bboxes, 4*y_rpn_overlap + y_rpn_regr)
			y_rpn_regr: x1,y1,x2,y2 bunding boxes coordinates
	"""
	downscale = float(C.rpn_stride) 
	anchor_sizes = C.anchor_box_scales   # 128, 256, 512
	anchor_ratios = C.anchor_box_ratios  # 1:1, 1:2*sqrt(2), 2*sqrt(2):1
	num_anchors = len(anchor_sizes) * len(anchor_ratios) # 3x3=9

	# calculate the output map size based on the network architecture
	(output_width, output_height) = img_length_calc_function(resized_width, resized_height)

	n_anchratios = len(anchor_ratios)    # 3
	
	# initialise empty output objectives
	y_rpn_overlap = np.zeros((output_height, output_width, num_anchors))
	y_is_box_valid = np.zeros((output_height, output_width, num_anchors))
	y_rpn_regr = np.zeros((output_height, output_width, num_anchors * 4))

	num_bboxes = len(img_data['bboxes'])

	num_anchors_for_bbox = np.zeros(num_bboxes).astype(int)
	best_anchor_for_bbox = -1*np.ones((num_bboxes, 4)).astype(int)
	best_iou_for_bbox = np.zeros(num_bboxes).astype(np.float32)
	best_x_for_bbox = np.zeros((num_bboxes, 4)).astype(int)
	best_dx_for_bbox = np.zeros((num_bboxes, 4)).astype(np.float32)

	# get the GT box coordinates, and resize to account for image resizing
	gta = np.zeros((num_bboxes, 4))
	for bbox_num, bbox in enumerate(img_data['bboxes']):
		# get the GT box coordinates, and resize to account for image resizing
		gta[bbox_num, 0] = bbox['x1'] * (resized_width / float(width))
		gta[bbox_num, 1] = bbox['x2'] * (resized_width / float(width))
		gta[bbox_num, 2] = bbox['y1'] * (resized_height / float(height))
		gta[bbox_num, 3] = bbox['y2'] * (resized_height / float(height))
	
	# rpn ground truth

	for anchor_size_idx in range(len(anchor_sizes)):
		for anchor_ratio_idx in range(n_anchratios):
			anchor_x = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][0]
			anchor_y = anchor_sizes[anchor_size_idx] * anchor_ratios[anchor_ratio_idx][1]	
			
			for ix in range(output_width):					
				# x-coordinates of the current anchor box	
				x1_anc = downscale * (ix + 0.5) - anchor_x / 2
				x2_anc = downscale * (ix + 0.5) + anchor_x / 2	
				
				# ignore boxes that go across image boundaries					
				if x1_anc < 0 or x2_anc > resized_width:
					continue
					
				for jy in range(output_height):

					# y-coordinates of the current anchor box
					y1_anc = downscale * (jy + 0.5) - anchor_y / 2
					y2_anc = downscale * (jy + 0.5) + anchor_y / 2

					# ignore boxes that go across image boundaries
					if y1_anc < 0 or y2_anc > resized_height:
						continue

					# bbox_type indicates whether an anchor should be a target
					# Initialize with 'negative'
					bbox_type = 'neg'

					# this is the best IOU for the (x,y) coord and the current anchor
					# note that this is different from the best IOU for a GT bbox
					best_iou_for_loc = 0.0

					for bbox_num in range(num_bboxes):
						
						# get IOU of the current GT box and the current anchor box
						curr_iou = iou([gta[bbox_num, 0], gta[bbox_num, 2], gta[bbox_num, 1], gta[bbox_num, 3]], [x1_anc, y1_anc, x2_anc, y2_anc])
						# calculate the regression targets if they will be needed
						if curr_iou > best_iou_for_bbox[bbox_num] or curr_iou > C.rpn_max_overlap:
							cx = (gta[bbox_num, 0] + gta[bbox_num, 1]) / 2.0
							cy = (gta[bbox_num, 2] + gta[bbox_num, 3]) / 2.0
							cxa = (x1_anc + x2_anc)/2.0
							cya = (y1_anc + y2_anc)/2.0

							# x,y are the center point of ground-truth bbox
							# xa,ya are the center point of anchor bbox (xa=downscale * (ix + 0.5); ya=downscale * (iy+0.5))
							# w,h are the width and height of ground-truth bbox
							# wa,ha are the width and height of anchor bboxe
							# tx = (x - xa) / wa
							# ty = (y - ya) / ha
							# tw = log(w / wa)
							# th = log(h / ha)
							tx = (cx - cxa) / (x2_anc - x1_anc)
							ty = (cy - cya) / (y2_anc - y1_anc)
							tw = np.log((gta[bbox_num, 1] - gta[bbox_num, 0]) / (x2_anc - x1_anc))
							th = np.log((gta[bbox_num, 3] - gta[bbox_num, 2]) / (y2_anc - y1_anc))
						
						if img_data['bboxes'][bbox_num]['class'] != 'bg':

							# all GT boxes should be mapped to an anchor box, so we keep track of which anchor box was best
							if curr_iou > best_iou_for_bbox[bbox_num]:
								best_anchor_for_bbox[bbox_num] = [jy, ix, anchor_ratio_idx, anchor_size_idx]
								best_iou_for_bbox[bbox_num] = curr_iou
								best_x_for_bbox[bbox_num,:] = [x1_anc, x2_anc, y1_anc, y2_anc]
								best_dx_for_bbox[bbox_num,:] = [tx, ty, tw, th]

							# we set the anchor to positive if the IOU is >0.7 (it does not matter if there was another better box, it just indicates overlap)
							if curr_iou > C.rpn_max_overlap:
								bbox_type = 'pos'
								num_anchors_for_bbox[bbox_num] += 1
								# we update the regression layer target if this IOU is the best for the current (x,y) and anchor position
								if curr_iou > best_iou_for_loc:
									best_iou_for_loc = curr_iou
									best_regr = (tx, ty, tw, th)

							# if the IOU is >0.3 and <0.7, it is ambiguous and no included in the objective
							if C.rpn_min_overlap < curr_iou < C.rpn_max_overlap:
								# gray zone between neg and pos
								if bbox_type != 'pos':
									bbox_type = 'neutral'

					# turn on or off outputs depending on IOUs
					if bbox_type == 'neg':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'neutral':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 0
					elif bbox_type == 'pos':
						y_is_box_valid[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						y_rpn_overlap[jy, ix, anchor_ratio_idx + n_anchratios * anchor_size_idx] = 1
						start = 4 * (anchor_ratio_idx + n_anchratios * anchor_size_idx)
						y_rpn_regr[jy, ix, start:start+4] = best_regr

	# we ensure that every bbox has at least one positive RPN region

	for idx in range(num_anchors_for_bbox.shape[0]):
		if num_anchors_for_bbox[idx] == 0:
			# no box with an IOU greater than zero ...
			if best_anchor_for_bbox[idx, 0] == -1:
				continue
			y_is_box_valid[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			y_rpn_overlap[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], best_anchor_for_bbox[idx,2] + n_anchratios *
				best_anchor_for_bbox[idx,3]] = 1
			start = 4 * (best_anchor_for_bbox[idx,2] + n_anchratios * best_anchor_for_bbox[idx,3])
			y_rpn_regr[
				best_anchor_for_bbox[idx,0], best_anchor_for_bbox[idx,1], start:start+4] = best_dx_for_bbox[idx, :]

	y_rpn_overlap = np.transpose(y_rpn_overlap, (2, 0, 1))
	y_rpn_overlap = np.expand_dims(y_rpn_overlap, axis=0)

	y_is_box_valid = np.transpose(y_is_box_valid, (2, 0, 1))
	y_is_box_valid = np.expand_dims(y_is_box_valid, axis=0)

	y_rpn_regr = np.transpose(y_rpn_regr, (2, 0, 1))
	y_rpn_regr = np.expand_dims(y_rpn_regr, axis=0)

	pos_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 1, y_is_box_valid[0, :, :, :] == 1))
	neg_locs = np.where(np.logical_and(y_rpn_overlap[0, :, :, :] == 0, y_is_box_valid[0, :, :, :] == 1))

	num_pos = len(pos_locs[0])

	# one issue is that the RPN has many more negative than positive regions, so we turn off some of the negative
	# regions. We also limit it to 256 regions.
	num_regions = 256

	if len(pos_locs[0]) > num_regions/2:
		val_locs = random.sample(range(len(pos_locs[0])), len(pos_locs[0]) - num_regions/2)
		y_is_box_valid[0, pos_locs[0][val_locs], pos_locs[1][val_locs], pos_locs[2][val_locs]] = 0
		num_pos = num_regions/2

	if len(neg_locs[0]) + num_pos > num_regions:
		val_locs = random.sample(range(len(neg_locs[0])), len(neg_locs[0]) - num_pos)
		y_is_box_valid[0, neg_locs[0][val_locs], neg_locs[1][val_locs], neg_locs[2][val_locs]] = 0

	y_rpn_cls = np.concatenate([y_is_box_valid, y_rpn_overlap], axis=1)
	y_rpn_regr = np.concatenate([np.repeat(y_rpn_overlap, 4, axis=1), y_rpn_regr], axis=1)

	return np.copy(y_rpn_cls), np.copy(y_rpn_regr), num_pos

# %% [markdown]
# #### Get new image size and augment the image

# %%
def get_new_img_size(width, height, img_min_side=300):
	if width <= height:
		f = float(img_min_side) / width
		resized_height = int(f * height)
		resized_width = img_min_side
	else:
		f = float(img_min_side) / height
		resized_width = int(f * width)
		resized_height = img_min_side

	return resized_width, resized_height

def augment(img_data, config, augment=True):
	assert 'filepath' in img_data
	assert 'bboxes' in img_data
	assert 'width' in img_data
	assert 'height' in img_data

	img_data_aug = copy.deepcopy(img_data)

	img = cv2.imread(img_data_aug['filepath'])

	if augment:
		rows, cols = img.shape[:2]

		if config.use_horizontal_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 1)
			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				bbox['x2'] = cols - x1
				bbox['x1'] = cols - x2

		if config.use_vertical_flips and np.random.randint(0, 2) == 0:
			img = cv2.flip(img, 0)
			for bbox in img_data_aug['bboxes']:
				y1 = bbox['y1']
				y2 = bbox['y2']
				bbox['y2'] = rows - y1
				bbox['y1'] = rows - y2

		if config.rot_90:
			angle = np.random.choice([0,90,180,270],1)[0]
			if angle == 270:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 0)
			elif angle == 180:
				img = cv2.flip(img, -1)
			elif angle == 90:
				img = np.transpose(img, (1,0,2))
				img = cv2.flip(img, 1)
			elif angle == 0:
				pass

			for bbox in img_data_aug['bboxes']:
				x1 = bbox['x1']
				x2 = bbox['x2']
				y1 = bbox['y1']
				y2 = bbox['y2']
				if angle == 270:
					bbox['x1'] = y1
					bbox['x2'] = y2
					bbox['y1'] = cols - x2
					bbox['y2'] = cols - x1
				elif angle == 180:
					bbox['x2'] = cols - x1
					bbox['x1'] = cols - x2
					bbox['y2'] = rows - y1
					bbox['y1'] = rows - y2
				elif angle == 90:
					bbox['x1'] = rows - y2
					bbox['x2'] = rows - y1
					bbox['y1'] = x1
					bbox['y2'] = x2        
				elif angle == 0:
					pass

	img_data_aug['width'] = img.shape[1]
	img_data_aug['height'] = img.shape[0]
	return img_data_aug, img

# %% [markdown]
# #### Generate the ground_truth anchors

# %%
def get_anchor_gt(all_img_data, C, img_length_calc_function, mode='train'):
	""" Yield the ground-truth anchors as Y (labels)
		
	Args:
		all_img_data: list(filepath, width, height, list(bboxes))
		C: config
		img_length_calc_function: function to calculate final layer's feature map (of base model) size according to input image size
		mode: 'train' or 'test'; 'train' mode need augmentation

	Returns:
		x_img: image data after resized and scaling (smallest size = 300px)
		Y: [y_rpn_cls, y_rpn_regr]
		img_data_aug: augmented image data (original image with augmentation)
		debug_img: show image for debug
		num_pos: show number of positive anchors for debug
	"""
	while True:

		for img_data in all_img_data:
			try:

				# read in image, and optionally add augmentation

				if mode == 'train':
					img_data_aug, x_img = augment(img_data, C, augment=True)
				else:
					img_data_aug, x_img = augment(img_data, C, augment=False)

				(width, height) = (img_data_aug['width'], img_data_aug['height'])
				(rows, cols, _) = x_img.shape

				assert cols == width
				assert rows == height

				# get image dimensions for resizing
				(resized_width, resized_height) = get_new_img_size(width, height, C.im_size)

				# resize the image so that smalles side is length = 300px
				x_img = cv2.resize(x_img, (resized_width, resized_height), interpolation=cv2.INTER_CUBIC)
				debug_img = x_img.copy()

				try:
					y_rpn_cls, y_rpn_regr, num_pos = calc_rpn(C, img_data_aug, width, height, resized_width, resized_height, img_length_calc_function)
				except:
					continue

				# Zero-center by mean pixel, and preprocess image

				x_img = x_img[:,:, (2, 1, 0)]  # BGR -> RGB
				x_img = x_img.astype(np.float32)
				x_img[:, :, 0] -= C.img_channel_mean[0]
				x_img[:, :, 1] -= C.img_channel_mean[1]
				x_img[:, :, 2] -= C.img_channel_mean[2]
				x_img /= C.img_scaling_factor

				x_img = np.transpose(x_img, (2, 0, 1))
				x_img = np.expand_dims(x_img, axis=0)

				y_rpn_regr[:, y_rpn_regr.shape[1]//2:, :, :] *= C.std_scaling

				x_img = np.transpose(x_img, (0, 2, 3, 1))
				y_rpn_cls = np.transpose(y_rpn_cls, (0, 2, 3, 1))
				y_rpn_regr = np.transpose(y_rpn_regr, (0, 2, 3, 1))

				yield np.copy(x_img), [np.copy(y_rpn_cls), np.copy(y_rpn_regr)], img_data_aug, debug_img, num_pos

			except Exception as e:
				print(e)
				continue

# %%
def non_max_suppression_fast(boxes, probs, overlap_thresh=0.9, max_boxes=300):
	# code used from here: http://www.pyimagesearch.com/2015/02/16/faster-non-maximum-suppression-python/
	# if there are no boxes, return an empty list
  
    # Process explanation:
    #   Step 1: Sort the probs list
    #   Step 2: Find the larget prob 'Last' in the list and save it to the pick list
    #   Step 3: Calculate the IoU with 'Last' box and other boxes in the list. If the IoU is larger than overlap_threshold, delete the box from list
    #   Step 4: Repeat step 2 and step 3 until there is no item in the probs list 
	if len(boxes) == 0:
		return []

	# grab the coordinates of the bounding boxes
	x1 = boxes[:, 0]
	y1 = boxes[:, 1]
	x2 = boxes[:, 2]
	y2 = boxes[:, 3]

	np.testing.assert_array_less(x1, x2)
	np.testing.assert_array_less(y1, y2)

	# if the bounding boxes integers, convert them to floats --
	# this is important since we'll be doing a bunch of divisions
	if boxes.dtype.kind == "i":
		boxes = boxes.astype("float")

	# initialize the list of picked indexes	
	pick = []

	# calculate the areas
	area = (x2 - x1) * (y2 - y1)

	# sort the bounding boxes 
	idxs = np.argsort(probs)

	# keep looping while some indexes still remain in the indexes
	# list
	while len(idxs) > 0:
		# grab the last index in the indexes list and add the
		# index value to the list of picked indexes
		last = len(idxs) - 1
		i = idxs[last]
		pick.append(i)

		# find the intersection

		xx1_int = np.maximum(x1[i], x1[idxs[:last]])
		yy1_int = np.maximum(y1[i], y1[idxs[:last]])
		xx2_int = np.minimum(x2[i], x2[idxs[:last]])
		yy2_int = np.minimum(y2[i], y2[idxs[:last]])

		ww_int = np.maximum(0, xx2_int - xx1_int)
		hh_int = np.maximum(0, yy2_int - yy1_int)

		area_int = ww_int * hh_int

		# find the union
		area_union = area[i] + area[idxs[:last]] - area_int

		# compute the ratio of overlap
		overlap = area_int/(area_union + 1e-6)

		# delete all indexes from the index list that have
		idxs = np.delete(idxs, np.concatenate(([last],
			np.where(overlap > overlap_thresh)[0])))

		if len(pick) >= max_boxes:
			break

	# return only the bounding boxes that were picked using the integer data type
	boxes = boxes[pick].astype("int")
	probs = probs[pick]
	return boxes, probs

def apply_regr_np(X, T):
	"""Apply regression layer to all anchors in one feature map

	Args:
		X: shape=(4, 18, 25) the current anchor type for all points in the feature map
		T: regression layer shape=(4, 18, 25)

	Returns:
		X: regressed position and size for current anchor
	"""
	try:
		x = X[0, :, :]
		y = X[1, :, :]
		w = X[2, :, :]
		h = X[3, :, :]

		tx = T[0, :, :]
		ty = T[1, :, :]
		tw = T[2, :, :]
		th = T[3, :, :]

		cx = x + w/2.
		cy = y + h/2.
		cx1 = tx * w + cx
		cy1 = ty * h + cy

		w1 = np.exp(tw.astype(np.float64)) * w
		h1 = np.exp(th.astype(np.float64)) * h
		x1 = cx1 - w1/2.
		y1 = cy1 - h1/2.

		x1 = np.round(x1)
		y1 = np.round(y1)
		w1 = np.round(w1)
		h1 = np.round(h1)
		return np.stack([x1, y1, w1, h1])
	except Exception as e:
		print(e)
		return X
    
def apply_regr(x, y, w, h, tx, ty, tw, th):
    # Apply regression to x, y, w and h
	try:
		cx = x + w/2.
		cy = y + h/2.
		cx1 = tx * w + cx
		cy1 = ty * h + cy
		w1 = math.exp(tw) * w
		h1 = math.exp(th) * h
		x1 = cx1 - w1/2.
		y1 = cy1 - h1/2.
		x1 = int(round(x1))
		y1 = int(round(y1))
		w1 = int(round(w1))
		h1 = int(round(h1))

		return x1, y1, w1, h1

	except ValueError:
		return x, y, w, h
	except OverflowError:
		return x, y, w, h
	except Exception as e:
		print(e)
		return x, y, w, h

# %%
def rpn_to_roi(rpn_layer, regr_layer, C, dim_ordering, use_regr=True, max_boxes=300,overlap_thresh=0.9):
	"""Convert rpn layer to roi bboxes

	Args: (num_anchors = 9)
		rpn_layer: output layer for rpn classification 
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 9) if resized image is 400 width and 300
		regr_layer: output layer for rpn regression
			shape (1, feature_map.height, feature_map.width, num_anchors)
			Might be (1, 18, 25, 36) if resized image is 400 width and 300
		C: config
		use_regr: Wether to use bboxes regression in rpn
		max_boxes: max bboxes number for non-max-suppression (NMS)
		overlap_thresh: If iou in NMS is larger than this threshold, drop the box

	Returns:
		result: boxes from non-max-suppression (shape=(300, 4))
			boxes: coordinates for bboxes (on the feature map)
	"""
	regr_layer = regr_layer / C.std_scaling

	anchor_sizes = C.anchor_box_scales   # (3 in here)
	anchor_ratios = C.anchor_box_ratios  # (3 in here)

	assert rpn_layer.shape[0] == 1

	(rows, cols) = rpn_layer.shape[1:3]

	curr_layer = 0

	# A.shape = (4, feature_map.height, feature_map.width, num_anchors) 
	# Might be (4, 18, 25, 9) if resized image is 400 width and 300
	# A is the coordinates for 9 anchors for every point in the feature map 
	# => all 18x25x9=4050 anchors cooridnates
	A = np.zeros((4, rpn_layer.shape[1], rpn_layer.shape[2], rpn_layer.shape[3]))

	for anchor_size in anchor_sizes:
		for anchor_ratio in anchor_ratios:
			# anchor_x = (128 * 1) / 16 = 8  => width of current anchor
			# anchor_y = (128 * 2) / 16 = 16 => height of current anchor
			anchor_x = (anchor_size * anchor_ratio[0])/C.rpn_stride
			anchor_y = (anchor_size * anchor_ratio[1])/C.rpn_stride
			
			# curr_layer: 0~8 (9 anchors)
			# the Kth anchor of all position in the feature map (9th in total)
			regr = regr_layer[0, :, :, 4 * curr_layer:4 * curr_layer + 4] # shape => (18, 25, 4)
			regr = np.transpose(regr, (2, 0, 1)) # shape => (4, 18, 25)

			# Create 18x25 mesh grid
			# For every point in x, there are all the y points and vice versa
			# X.shape = (18, 25)
			# Y.shape = (18, 25)
			X, Y = np.meshgrid(np.arange(cols),np. arange(rows))

			# Calculate anchor position and size for each feature map point
			A[0, :, :, curr_layer] = X - anchor_x/2 # Top left x coordinate
			A[1, :, :, curr_layer] = Y - anchor_y/2 # Top left y coordinate
			A[2, :, :, curr_layer] = anchor_x       # width of current anchor
			A[3, :, :, curr_layer] = anchor_y       # height of current anchor

			# Apply regression to x, y, w and h if there is rpn regression layer
			if use_regr:
				A[:, :, :, curr_layer] = apply_regr_np(A[:, :, :, curr_layer], regr)

			# Avoid width and height exceeding 1
			A[2, :, :, curr_layer] = np.maximum(1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.maximum(1, A[3, :, :, curr_layer])

			# Convert (x, y , w, h) to (x1, y1, x2, y2)
			# x1, y1 is top left coordinate
			# x2, y2 is bottom right coordinate
			A[2, :, :, curr_layer] += A[0, :, :, curr_layer]
			A[3, :, :, curr_layer] += A[1, :, :, curr_layer]

			# Avoid bboxes drawn outside the feature map
			A[0, :, :, curr_layer] = np.maximum(0, A[0, :, :, curr_layer])
			A[1, :, :, curr_layer] = np.maximum(0, A[1, :, :, curr_layer])
			A[2, :, :, curr_layer] = np.minimum(cols-1, A[2, :, :, curr_layer])
			A[3, :, :, curr_layer] = np.minimum(rows-1, A[3, :, :, curr_layer])

			curr_layer += 1

	all_boxes = np.reshape(A.transpose((0, 3, 1, 2)), (4, -1)).transpose((1, 0))  # shape=(4050, 4)
	all_probs = rpn_layer.transpose((0, 3, 1, 2)).reshape((-1))                   # shape=(4050,)

	x1 = all_boxes[:, 0]
	y1 = all_boxes[:, 1]
	x2 = all_boxes[:, 2]
	y2 = all_boxes[:, 3]

	# Find out the bboxes which is illegal and delete them from bboxes list
	idxs = np.where((x1 - x2 >= 0) | (y1 - y2 >= 0))

	all_boxes = np.delete(all_boxes, idxs, 0)
	all_probs = np.delete(all_probs, idxs, 0)

	# Apply non_max_suppression
	# Only extract the bboxes. Don't need rpn probs in the later process
	result = non_max_suppression_fast(all_boxes, all_probs, overlap_thresh=overlap_thresh, max_boxes=max_boxes)[0]

	return result

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
base_path = '/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2'

test_path = '/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/test2022.txt' # Test data (annotation file)

test_base_path = '/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/dataset/test2022' # Directory to save the test images

config_output_filename = os.path.join(base_path, 'model_vgg_config2022.pickle')

# %%
with open(config_output_filename, 'rb') as f_in:
	C = pickle.load(f_in)

# turn off any data augmentation at test time
C.use_horizontal_flips = False
C.use_vertical_flips = False
C.rot_90 = False

# %%
# Load the records
record_df = pd.read_csv(C.record_path)

r_epochs = len(record_df)

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['mean_overlapping_bboxes'], 'r')
plt.title('mean_overlapping_bboxes')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['class_acc'], 'r')
plt.title('class_acc')

plt.show()

plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_cls'], 'r')
plt.title('loss_rpn_cls')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['loss_rpn_regr'], 'r')
plt.title('loss_rpn_regr')
plt.show()
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['loss_class_cls'], 'r')
plt.title('loss_class_cls')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['loss_class_regr'], 'r')
plt.title('loss_class_regr')
plt.show()
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(np.arange(0, r_epochs), record_df['curr_loss'], 'r')
plt.title('total_loss')

plt.subplot(1,2,2)
plt.plot(np.arange(0, r_epochs), record_df['elapsed_time'], 'r')
plt.title('elapsed_time')

plt.show()

# %% [markdown]
# # Test

# %%
def format_img_size(img, C):
	""" formats the image size based on config """
	img_min_side = float(C.im_size)
	(height,width,_) = img.shape
		
	if width <= height:
		ratio = img_min_side/width
		new_height = int(ratio * height)
		new_width = int(img_min_side)
	else:
		ratio = img_min_side/height
		new_width = int(ratio * width)
		new_height = int(img_min_side)
	img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
	return img, ratio	

def format_img_channels(img, C):
	""" formats the image channels based on config """
	img = img[:, :, (2, 1, 0)]
	img = img.astype(np.float32)
	img[:, :, 0] -= C.img_channel_mean[0]
	img[:, :, 1] -= C.img_channel_mean[1]
	img[:, :, 2] -= C.img_channel_mean[2]
	img /= C.img_scaling_factor
	img = np.transpose(img, (2, 0, 1))
	img = np.expand_dims(img, axis=0)
	return img

def format_img(img, C):
	""" formats an image for model prediction based on config """
	img, ratio = format_img_size(img, C)
	img = format_img_channels(img, C)
	return img, ratio

# Method to transform the coordinates of the bounding box to its original size
def get_real_coordinates(ratio, x1, y1, x2, y2):

	real_x1 = int(round(x1 // ratio))
	real_y1 = int(round(y1 // ratio))
	real_x2 = int(round(x2 // ratio))
	real_y2 = int(round(y2 // ratio))

	return (real_x1, real_y1, real_x2 ,real_y2)

# %%
num_features = 512

input_shape_img = (None, None, 3)
input_shape_features = (None, None, num_features)

img_input = Input(shape=input_shape_img)
roi_input = Input(shape=(C.num_rois, 4))
feature_map_input = Input(shape=input_shape_features)

# define the base network (VGG here, can be Resnet50, Inception, etc)
shared_layers = nn_base(img_input, trainable=True)

# define the RPN, built on the base layers
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
rpn_layers = rpn_layer(shared_layers, num_anchors)

classifier = classifier_layer(feature_map_input, roi_input, C.num_rois, nb_classes=len(C.class_mapping))

model_rpn = Model(img_input, rpn_layers)
model_classifier_only = Model([feature_map_input, roi_input], classifier)

model_classifier = Model([feature_map_input, roi_input], classifier)

print('Loading weights from {}'.format(C.model_path))
model_rpn.load_weights(C.model_path, by_name=True)
model_classifier.load_weights(C.model_path, by_name=True)

model_rpn.compile(optimizer='sgd', loss='mse')
model_classifier.compile(optimizer='sgd', loss='mse')
# Out:
# Loading weights from /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/model/model_frcnn_vgg2022.hdf5

# %%
# Switch key value for class mapping
class_mapping = C.class_mapping
class_mapping = {v: k for k, v in class_mapping.items()}
print(class_mapping)
class_to_color = {class_mapping[v]: np.random.randint(0, 255, 3) for v in class_mapping}
# Out:
# {0: 'Elephant', 1: 'Owl', 2: 'bg'}

# %%
test_imgs = os.listdir(test_base_path)

imgs_path = []
for i in range(12):
	idx = np.random.randint(len(test_imgs))
	imgs_path.append(test_imgs[idx])

all_imgs = []

classes = {}

# %%
# If the box classification value is less than this, we ignore this box
bbox_threshold = 0.7

for idx, img_name in enumerate(imgs_path):
    if not img_name.lower().endswith(('.bmp', '.jpeg', '.jpg', '.png', '.tif', '.tiff')):
        continue
    print(img_name)
    st = time.time()
    filepath = os.path.join(test_base_path, img_name)

    img = cv2.imread(filepath)

    X, ratio = format_img(img, C)
    
    X = np.transpose(X, (0, 2, 3, 1))

    # get output layer Y1, Y2 from the RPN and the feature maps F
    # Y1: y_rpn_cls
    # Y2: y_rpn_regr
    [Y1, Y2, F] = model_rpn.predict(X)

    # Get bboxes by applying NMS 
    # R.shape = (300, 4)
    #R = rpn_to_roi(Y1, Y2, C, K.image_dim_ordering(), overlap_thresh=0.7)
    R = rpn_to_roi(Y1, Y2, C, K.image_data_format(), overlap_thresh=0.7)

    # convert from (x1,y1,x2,y2) to (x,y,w,h)
    R[:, 2] -= R[:, 0]
    R[:, 3] -= R[:, 1]

    # apply the spatial pyramid pooling to the proposed regions
    bboxes = {}
    probs = {}

    for jk in range(R.shape[0]//C.num_rois + 1):
        ROIs = np.expand_dims(R[C.num_rois*jk:C.num_rois*(jk+1), :], axis=0)
        if ROIs.shape[1] == 0:
            break

        if jk == R.shape[0]//C.num_rois:
            #pad R
            curr_shape = ROIs.shape
            target_shape = (curr_shape[0],C.num_rois,curr_shape[2])
            ROIs_padded = np.zeros(target_shape).astype(ROIs.dtype)
            ROIs_padded[:, :curr_shape[1], :] = ROIs
            ROIs_padded[0, curr_shape[1]:, :] = ROIs[0, 0, :]
            ROIs = ROIs_padded

        [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])

        # Calculate bboxes coordinates on resized image
        for ii in range(P_cls.shape[1]):
            # Ignore 'bg' class
            if np.max(P_cls[0, ii, :]) < bbox_threshold or np.argmax(P_cls[0, ii, :]) == (P_cls.shape[2] - 1):
                continue

            cls_name = class_mapping[np.argmax(P_cls[0, ii, :])]

            if cls_name not in bboxes:
                bboxes[cls_name] = []
                probs[cls_name] = []

            (x, y, w, h) = ROIs[0, ii, :]

            cls_num = np.argmax(P_cls[0, ii, :])
            try:
                (tx, ty, tw, th) = P_regr[0, ii, 4*cls_num:4*(cls_num+1)]
                tx /= C.classifier_regr_std[0]
                ty /= C.classifier_regr_std[1]
                tw /= C.classifier_regr_std[2]
                th /= C.classifier_regr_std[3]
                x, y, w, h = apply_regr(x, y, w, h, tx, ty, tw, th)
            except:
                pass
            bboxes[cls_name].append([C.rpn_stride*x, C.rpn_stride*y, C.rpn_stride*(x+w), C.rpn_stride*(y+h)])
            probs[cls_name].append(np.max(P_cls[0, ii, :]))

    all_dets = []

    for key in bboxes:
        bbox = np.array(bboxes[key])

        new_boxes, new_probs = non_max_suppression_fast(bbox, np.array(probs[key]), overlap_thresh=0.2)
        for jk in range(new_boxes.shape[0]):
            (x1, y1, x2, y2) = new_boxes[jk,:]

            # Calculate real coordinates on original image
            (real_x1, real_y1, real_x2, real_y2) = get_real_coordinates(ratio, x1, y1, x2, y2)

            cv2.rectangle(img,(real_x1, real_y1), (real_x2, real_y2), (int(class_to_color[key][0]), int(class_to_color[key][1]), int(class_to_color[key][2])),4)

            textLabel = '{}: {}'.format(key,int(100*new_probs[jk]))
            all_dets.append((key,100*new_probs[jk]))

            (retval,baseLine) = cv2.getTextSize(textLabel,cv2.FONT_HERSHEY_COMPLEX,1,1)
            textOrg = (real_x1, real_y1-0)

            cv2.rectangle(img, (textOrg[0] - 5, textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (0, 0, 0), 1)
            cv2.rectangle(img, (textOrg[0] - 5,textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (255, 255, 255), -1)
            cv2.putText(img, textLabel, textOrg, cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 0), 1)

    print('Elapsed time = {}'.format(time.time() - st))
    print(all_dets)
    plt.figure(figsize=(10,10))
    plt.grid()
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### Measure mAP

# %%
def get_map(pred, gt, f):
	T = {}
	P = {}
	fx, fy = f

	for bbox in gt:
		bbox['bbox_matched'] = False

	pred_probs = np.array([s['prob'] for s in pred])
	box_idx_sorted_by_prob = np.argsort(pred_probs)[::-1]

	for box_idx in box_idx_sorted_by_prob:
		pred_box = pred[box_idx]
		pred_class = pred_box['class']
		pred_x1 = pred_box['x1']
		pred_x2 = pred_box['x2']
		pred_y1 = pred_box['y1']
		pred_y2 = pred_box['y2']
		pred_prob = pred_box['prob']
		if pred_class not in P:
			P[pred_class] = []
			T[pred_class] = []
		P[pred_class].append(pred_prob)
		found_match = False

		for gt_box in gt:
			gt_class = gt_box['class']
			gt_x1 = gt_box['x1']/fx
			gt_x2 = gt_box['x2']/fx
			gt_y1 = gt_box['y1']/fy
			gt_y2 = gt_box['y2']/fy
			gt_seen = gt_box['bbox_matched']
			if gt_class != pred_class:
				continue
			if gt_seen:
				continue
			iou_map = iou((pred_x1, pred_y1, pred_x2, pred_y2), (gt_x1, gt_y1, gt_x2, gt_y2))
			if iou_map >= 0.5:
				found_match = True
				gt_box['bbox_matched'] = True
				break
			else:
				continue

		T[pred_class].append(int(found_match))

	for gt_box in gt:
		if not gt_box['bbox_matched']:# and not gt_box['difficult']:
			if gt_box['class'] not in P:
				P[gt_box['class']] = []
				T[gt_box['class']] = []

			T[gt_box['class']].append(1)
			P[gt_box['class']].append(0)

	#import pdb
	#pdb.set_trace()
	return T, P

# %%
def format_img_map(img, C):
	"""Format image for mAP. Resize original image to C.im_size (300 in here)

	Args:
		img: cv2 image
		C: config

	Returns:
		img: Scaled and normalized image with expanding dimension
		fx: ratio for width scaling
		fy: ratio for height scaling
	"""

	img_min_side = float(C.im_size)
	(height,width,_) = img.shape
	
	if width <= height:
		f = img_min_side/width
		new_height = int(f * height)
		new_width = int(img_min_side)
	else:
		f = img_min_side/height
		new_width = int(f * width)
		new_height = int(img_min_side)
	fx = width/float(new_width)
	fy = height/float(new_height)
	img = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_CUBIC)
	# Change image channel from BGR to RGB
	img = img[:, :, (2, 1, 0)]
	img = img.astype(np.float32)
	img[:, :, 0] -= C.img_channel_mean[0]
	img[:, :, 1] -= C.img_channel_mean[1]
	img[:, :, 2] -= C.img_channel_mean[2]
	img /= C.img_scaling_factor
	# Change img shape from (height, width, channel) to (channel, height, width)
	img = np.transpose(img, (2, 0, 1))
	# Expand one dimension at axis 0
	# img shape becames (1, channel, height, width)
	img = np.expand_dims(img, axis=0)
	return img, fx, fy

# %%
print(class_mapping)
# Out:
# {0: 'Elephant', 1: 'Owl', 2: 'bg'}

# %%
# This might takes a while to parser the data
test_imgs, _, _ = get_data(test_path)
# Out:
# Parsing annotation files
# idx=381

# %%
T = {}
P = {}
mAPs = []
for idx, img_data in enumerate(test_imgs):
    print('{}/{}'.format(idx,len(test_imgs)))
    st = time.time()
    filepath = img_data['filepath']

    img = cv2.imread(filepath)

    X, fx, fy = format_img_map(img, C)

    # Change X (img) shape from (1, channel, height, width) to (1, height, width, channel)
    X = np.transpose(X, (0, 2, 3, 1))

    # get the feature maps and output from the RPN
    [Y1, Y2, F] = model_rpn.predict(X)


    #R = rpn_to_roi(Y1, Y2, C, K.image_dim_ordering(), overlap_thresh=0.7)
    R = rpn_to_roi(Y1, Y2, C, K.image_data_format(), overlap_thresh=0.7)
    
    # convert from (x1,y1,x2,y2) to (x,y,w,h)
    R[:, 2] -= R[:, 0]
    R[:, 3] -= R[:, 1]

    # apply the spatial pyramid pooling to the proposed regions
    bboxes = {}
    probs = {}

    for jk in range(R.shape[0] // C.num_rois + 1):
        ROIs = np.expand_dims(R[C.num_rois * jk:C.num_rois * (jk + 1), :], axis=0)
        if ROIs.shape[1] == 0:
            break

        if jk == R.shape[0] // C.num_rois:
            # pad R
            curr_shape = ROIs.shape
            target_shape = (curr_shape[0], C.num_rois, curr_shape[2])
            ROIs_padded = np.zeros(target_shape).astype(ROIs.dtype)
            ROIs_padded[:, :curr_shape[1], :] = ROIs
            ROIs_padded[0, curr_shape[1]:, :] = ROIs[0, 0, :]
            ROIs = ROIs_padded

        [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])

        # Calculate all classes' bboxes coordinates on resized image (300, 400)
        # Drop 'bg' classes bboxes
        for ii in range(P_cls.shape[1]):

            # If class name is 'bg', continue
            if np.argmax(P_cls[0, ii, :]) == (P_cls.shape[2] - 1):
                continue

            # Get class name
            cls_name = class_mapping[np.argmax(P_cls[0, ii, :])]

            if cls_name not in bboxes:
                bboxes[cls_name] = []
                probs[cls_name] = []

            (x, y, w, h) = ROIs[0, ii, :]

            cls_num = np.argmax(P_cls[0, ii, :])
            try:
                (tx, ty, tw, th) = P_regr[0, ii, 4 * cls_num:4 * (cls_num + 1)]
                tx /= C.classifier_regr_std[0]
                ty /= C.classifier_regr_std[1]
                tw /= C.classifier_regr_std[2]
                th /= C.classifier_regr_std[3]
                x, y, w, h = roi_helpers.apply_regr(x, y, w, h, tx, ty, tw, th)
            except:
                pass
            bboxes[cls_name].append([16 * x, 16 * y, 16 * (x + w), 16 * (y + h)])
            probs[cls_name].append(np.max(P_cls[0, ii, :]))

    all_dets = []

    for key in bboxes:
        bbox = np.array(bboxes[key])

        # Apply non-max-suppression on final bboxes to get the output bounding boxe
        new_boxes, new_probs = non_max_suppression_fast(bbox, np.array(probs[key]), overlap_thresh=0.5)
        for jk in range(new_boxes.shape[0]):
            (x1, y1, x2, y2) = new_boxes[jk, :]
            det = {'x1': x1, 'x2': x2, 'y1': y1, 'y2': y2, 'class': key, 'prob': new_probs[jk]}
            all_dets.append(det)


    print('Elapsed time = {}'.format(time.time() - st))
    t, p = get_map(all_dets, img_data['bboxes'], (fx, fy))
    for key in t.keys():
        if key not in T:
            T[key] = []
            P[key] = []
        T[key].extend(t[key])
        P[key].extend(p[key])
    all_aps = []
    for key in T.keys():
        ap = average_precision_score(T[key], P[key])
        print('{} AP: {}'.format(key, ap))
        all_aps.append(ap)
    print('mAP = {}'.format(np.mean(np.array(all_aps))))
    mAPs.append(np.mean(np.array(all_aps)))
    #print(T)
    #print(P)
    
print()
print('mean average precision:', np.mean(np.array(mAPs)))
# Out:
# 0/243
# Elapsed time = 5.69938063621521
# Owl AP: nan
# Elephant AP: 1.0
# mAP = nan
# 1/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.404622793197632
# Owl AP: nan
# Elephant AP: 0.625
# mAP = nan
# 2/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.352875232696533
# Owl AP: nan
# Elephant AP: 0.5909090909090908
# mAP = nan
# 3/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.571259021759033
# Owl AP: nan
# Elephant AP: 0.6626984126984127
# mAP = nan
# 4/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.653595924377441
# Owl AP: nan
# Elephant AP: 0.72
# mAP = nan
# 5/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.467184066772461
# Owl AP: nan
# Elephant AP: 0.6963876459674778
# mAP = nan
# 6/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.568542003631592
# Owl AP: nan
# Elephant AP: 0.6289084606677986
# mAP = nan
# 7/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.6480278968811035
# Owl AP: nan
# Elephant AP: 0.5965832413200834
# mAP = nan
# 8/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.42617130279541
# Owl AP: nan
# Elephant AP: 0.6035969844109379
# mAP = nan
# 9/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.6353678703308105
# Owl AP: nan
# Elephant AP: 0.5837912087912087
# mAP = nan
# 10/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.635105609893799
# Owl AP: nan
# Elephant AP: 0.5978361883038426
# mAP = nan
# 11/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.414520502090454
# Owl AP: nan
# Elephant AP: 0.5994233880609678
# mAP = nan
# 12/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.263867139816284
# Owl AP: nan
# Elephant AP: 0.6280667481932872
# mAP = nan
# 13/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.128057479858398
# Owl AP: nan
# Elephant AP: 0.6493247053037675
# mAP = nan
# 14/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.202533960342407
# Owl AP: nan
# Elephant AP: 0.6404626622418206
# mAP = nan
# 15/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.515664577484131
# Owl AP: nan
# Elephant AP: 0.6195609324625524
# mAP = nan
# 16/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.031849384307861
# Owl AP: nan
# Elephant AP: 0.6155493017383808
# mAP = nan
# 17/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.893168210983276
# Owl AP: nan
# Elephant AP: 0.5991311588226669
# mAP = nan
# 18/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.436198711395264
# Owl AP: nan
# Elephant AP: 0.5808603041583829
# mAP = nan
# 19/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.261845111846924
# Owl AP: nan
# Elephant AP: 0.5975313906323957
# mAP = nan
# 20/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.511702060699463
# Owl AP: nan
# Elephant AP: 0.5668937505294862
# mAP = nan
# 21/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.4041588306427
# Owl AP: nan
# Elephant AP: 0.5767697144194527
# mAP = nan
# 22/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.185391664505005
# Owl AP: nan
# Elephant AP: 0.5790276856703002
# mAP = nan
# 23/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.2907960414886475
# Owl AP: nan
# Elephant AP: 0.5855443821449977
# mAP = nan
# 24/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.300354242324829
# Owl AP: nan
# Elephant AP: 0.5989337967927869
# mAP = nan
# 25/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.308210372924805
# Owl AP: nan
# Elephant AP: 0.5851921928965749
# mAP = nan
# 26/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.470844984054565
# Owl AP: nan
# Elephant AP: 0.5702487324555697
# mAP = nan
# 27/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.520078182220459
# Owl AP: nan
# Elephant AP: 0.5854210526138469
# mAP = nan
# 28/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.386000394821167
# Owl AP: nan
# Elephant AP: 0.6148582002974861
# mAP = nan
# 29/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.502918004989624
# Owl AP: nan
# Elephant AP: 0.6075001655732657
# mAP = nan
# 30/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.728565454483032
# Owl AP: nan
# Elephant AP: 0.6087020870599664
# mAP = nan
# 31/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.011000156402588
# Owl AP: nan
# Elephant AP: 0.5993163580237613
# mAP = nan
# 32/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.683912754058838
# Owl AP: nan
# Elephant AP: 0.60340223531819
# mAP = nan
# 33/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.569566011428833
# Owl AP: nan
# Elephant AP: 0.5963138616491462
# mAP = nan
# 34/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.438198089599609
# Owl AP: nan
# Elephant AP: 0.5969143626868203
# mAP = nan
# 35/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.543126821517944
# Owl AP: nan
# Elephant AP: 0.5895046837265447
# mAP = nan
# 36/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.405132532119751
# Owl AP: nan
# Elephant AP: 0.5869245195191752
# mAP = nan
# 37/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.9460670948028564
# Owl AP: nan
# Elephant AP: 0.586486026151266
# mAP = nan
# 38/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.623730897903442
# Owl AP: nan
# Elephant AP: 0.589895050726745
# mAP = nan
# 39/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.3541905879974365
# Owl AP: nan
# Elephant AP: 0.5863758507961175
# mAP = nan
# 40/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.560068130493164
# Owl AP: nan
# Elephant AP: 0.5887657280246119
# mAP = nan
# 41/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.473386526107788
# Owl AP: nan
# Elephant AP: 0.5909298744532795
# mAP = nan
# 42/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.325621843338013
# Owl AP: nan
# Elephant AP: 0.5975904126228266
# mAP = nan
# 43/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.401219367980957
# Owl AP: nan
# Elephant AP: 0.6035722758109588
# mAP = nan
# 44/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.374448299407959
# Owl AP: nan
# Elephant AP: 0.603388688623577
# mAP = nan
# 45/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.238621234893799
# Owl AP: nan
# Elephant AP: 0.6082968774171724
# mAP = nan
# 46/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.8801069259643555
# Owl AP: nan
# Elephant AP: 0.6090536156366435
# mAP = nan
# 47/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.48877477645874
# Owl AP: nan
# Elephant AP: 0.6076784030629135
# mAP = nan
# 48/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.791574001312256
# Owl AP: nan
# Elephant AP: 0.6030253492300978
# mAP = nan
# 49/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.3919594287872314
# Owl AP: nan
# Elephant AP: 0.6097195422647164
# mAP = nan
# 50/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.672504186630249
# Owl AP: nan
# Elephant AP: 0.6075336105678419
# mAP = nan
# 51/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.17798638343811
# Owl AP: nan
# Elephant AP: 0.6089743898167809
# mAP = nan
# 52/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.193804502487183
# Owl AP: nan
# Elephant AP: 0.6003044428486574
# mAP = nan
# 53/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.147801637649536
# Owl AP: nan
# Elephant AP: 0.5952466388682777
# mAP = nan
# 54/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.379828929901123
# Owl AP: nan
# Elephant AP: 0.612151414738593
# mAP = nan
# 55/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.429731607437134
# Owl AP: nan
# Elephant AP: 0.6063751428646906
# mAP = nan
# 56/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.400646448135376
# Owl AP: nan
# Elephant AP: 0.6119131641488186
# mAP = nan
# 57/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.592534065246582
# Owl AP: nan
# Elephant AP: 0.6156894081975062
# mAP = nan
# 58/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.0699098110198975
# Owl AP: nan
# Elephant AP: 0.6076069089182563
# mAP = nan
# 59/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.3724048137664795
# Owl AP: nan
# Elephant AP: 0.5925643175784368
# mAP = nan
# 60/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.593059778213501
# Owl AP: nan
# Elephant AP: 0.5985904395166495
# mAP = nan
# 61/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.324785470962524
# Owl AP: nan
# Elephant AP: 0.59465037901164
# mAP = nan
# 62/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.385002613067627
# Owl AP: nan
# Elephant AP: 0.5877922967939572
# mAP = nan
# 63/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.546956539154053
# Owl AP: nan
# Elephant AP: 0.593129034619552
# mAP = nan
# 64/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.577811241149902
# Owl AP: nan
# Elephant AP: 0.5910505300273661
# mAP = nan
# 65/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.325493812561035
# Owl AP: nan
# Elephant AP: 0.5602682843819877
# mAP = nan
# 66/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.37091588973999
# Owl AP: nan
# Elephant AP: 0.564014250275694
# mAP = nan
# 67/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.738069295883179
# Owl AP: nan
# Elephant AP: 0.5656142463040806
# mAP = nan
# 68/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.442006587982178
# Owl AP: nan
# Elephant AP: 0.5651995310865724
# mAP = nan
# 69/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.393481969833374
# Owl AP: nan
# Elephant AP: 0.561913137062437
# mAP = nan
# 70/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.415981292724609
# Owl AP: nan
# Elephant AP: 0.5599190739983796
# mAP = nan
# 71/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.535176515579224
# Owl AP: nan
# Elephant AP: 0.563981024553477
# mAP = nan
# 72/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.256514549255371
# Owl AP: nan
# Elephant AP: 0.5599001738677902
# mAP = nan
# 73/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.47665548324585
# Owl AP: nan
# Elephant AP: 0.5606416128458356
# mAP = nan
# 74/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.332175254821777
# Owl AP: nan
# Elephant AP: 0.5613835635216902
# mAP = nan
# 75/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.448398590087891
# Owl AP: nan
# Elephant AP: 0.5603521331038552
# mAP = nan
# 76/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.080107688903809
# Owl AP: nan
# Elephant AP: 0.5580617454828266
# mAP = nan
# 77/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.337585926055908
# Owl AP: nan
# Elephant AP: 0.5608891008258154
# mAP = nan
# 78/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.44884729385376
# Owl AP: nan
# Elephant AP: 0.5674044430816428
# mAP = nan
# 79/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.431700944900513
# Owl AP: nan
# Elephant AP: 0.5627105280386778
# mAP = nan
# 80/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.387472629547119
# Owl AP: nan
# Elephant AP: 0.563087515905772
# mAP = nan
# 81/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.527488708496094
# Owl AP: nan
# Elephant AP: 0.5709611656033232
# mAP = nan
# 82/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.4880475997924805
# Owl AP: nan
# Elephant AP: 0.5700386945636302
# mAP = nan
# 83/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.293032169342041
# Owl AP: nan
# Elephant AP: 0.5685026180932333
# mAP = nan
# 84/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.328877687454224
# Owl AP: nan
# Elephant AP: 0.5649589778762324
# mAP = nan
# 85/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.68070125579834
# Owl AP: nan
# Elephant AP: 0.5683933498887183
# mAP = nan
# 86/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.626351356506348
# Owl AP: nan
# Elephant AP: 0.5676707343131675
# mAP = nan
# 87/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.228294610977173
# Owl AP: nan
# Elephant AP: 0.5678699130711283
# mAP = nan
# 88/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.598511457443237
# Owl AP: nan
# Elephant AP: 0.5736631295873359
# mAP = nan
# 89/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.182756423950195
# Owl AP: nan
# Elephant AP: 0.5749680816605631
# mAP = nan
# 90/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.1769678592681885
# Owl AP: nan
# Elephant AP: 0.5733693556382126
# mAP = nan
# 91/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.1072447299957275
# Owl AP: nan
# Elephant AP: 0.5746927947697859
# mAP = nan
# 92/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.259822368621826
# Owl AP: nan
# Elephant AP: 0.5752379452023761
# mAP = nan
# 93/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.209320306777954
# Owl AP: nan
# Elephant AP: 0.5727913959786176
# mAP = nan
# 94/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.1515562534332275
# Owl AP: nan
# Elephant AP: 0.5740360238070475
# mAP = nan
# 95/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.64190411567688
# Owl AP: nan
# Elephant AP: 0.5729248303407746
# mAP = nan
# 96/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.795361042022705
# Owl AP: nan
# Elephant AP: 0.5746759502948147
# mAP = nan
# 97/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.0897743701934814
# Owl AP: nan
# Elephant AP: 0.5783294857331259
# mAP = nan
# 98/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.507312297821045
# Owl AP: nan
# Elephant AP: 0.5807769503259039
# mAP = nan
# 99/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 4.987879753112793
# Owl AP: nan
# Elephant AP: 0.5783324115640259
# mAP = nan
# 100/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.220796346664429
# Owl AP: nan
# Elephant AP: 0.5800467415961134
# mAP = nan
# 101/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.14657187461853
# Owl AP: nan
# Elephant AP: 0.5781064313251363
# mAP = nan
# 102/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.252109527587891
# Owl AP: nan
# Elephant AP: 0.5805511954179406
# mAP = nan
# 103/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.225039482116699
# Owl AP: nan
# Elephant AP: 0.5823026083049005
# mAP = nan
# 104/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.377883672714233
# Owl AP: nan
# Elephant AP: 0.5848616778772995
# mAP = nan
# 105/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.460460901260376
# Owl AP: nan
# Elephant AP: 0.5873574424750909
# mAP = nan
# 106/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.480225563049316
# Owl AP: nan
# Elephant AP: 0.5894521578655887
# mAP = nan
# 107/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.820345878601074
# Owl AP: nan
# Elephant AP: 0.5905384363423174
# mAP = nan
# 108/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.071737289428711
# Owl AP: nan
# Elephant AP: 0.5918456709873083
# mAP = nan
# 109/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.5225231647491455
# Owl AP: nan
# Elephant AP: 0.5936374508893276
# mAP = nan
# 110/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.387298107147217
# Owl AP: nan
# Elephant AP: 0.5939943586155907
# mAP = nan
# 111/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.287377595901489
# Owl AP: nan
# Elephant AP: 0.5909570033843597
# mAP = nan
# 112/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 6.657807350158691
# Owl AP: nan
# Elephant AP: 0.5941702121620843
# mAP = nan
# 113/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.647383213043213
# Owl AP: nan
# Elephant AP: 0.594656366578231
# mAP = nan
# 114/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.714209079742432
# Owl AP: nan
# Elephant AP: 0.5985017421407552
# mAP = nan
# 115/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.685882806777954
# Owl AP: nan
# Elephant AP: 0.5996514470550147
# mAP = nan
# 116/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.396705627441406
# Owl AP: nan
# Elephant AP: 0.6025132490978229
# mAP = nan
# 117/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.392207384109497
# Owl AP: nan
# Elephant AP: 0.6032471259487369
# mAP = nan
# 118/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.499288558959961
# Owl AP: nan
# Elephant AP: 0.6055545291760097
# mAP = nan
# 119/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.302549600601196
# Owl AP: nan
# Elephant AP: 0.6023792304007504
# mAP = nan
# 120/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.157842636108398
# Owl AP: nan
# Elephant AP: 0.599350876525492
# mAP = nan
# 121/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.396144390106201
# Owl AP: nan
# Elephant AP: 0.5992788002174227
# mAP = nan
# 122/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.176861047744751
# Owl AP: nan
# Elephant AP: 0.5875955437476328
# mAP = nan
# 123/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.369523286819458
# Owl AP: nan
# Elephant AP: 0.5860761093702191
# mAP = nan
# 124/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.435643672943115
# Owl AP: nan
# Elephant AP: 0.5870864082881083
# mAP = nan
# 125/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.2047646045684814
# Owl AP: nan
# Elephant AP: 0.5878980108762657
# mAP = nan
# 126/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.249966621398926
# Owl AP: nan
# Elephant AP: 0.5851949430665259
# mAP = nan
# 127/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.195759296417236
# Owl AP: nan
# Elephant AP: 0.5856013680397038
# mAP = nan
# 128/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.210409641265869
# Owl AP: nan
# Elephant AP: 0.5871130567165868
# mAP = nan
# 129/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.099604368209839
# Owl AP: nan
# Elephant AP: 0.5857945353796414
# mAP = nan
# 130/243
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_ranking.py:864: RuntimeWarning: invalid value encountered in true_divide
#   recall = tps / tps[-1]
# Elapsed time = 5.166295051574707
# Owl AP: 0.1111111111111111
# Elephant AP: 0.5857945353796414
# mAP = 0.3484528232453763
# 131/243
# Elapsed time = 5.178274393081665
# Owl AP: 0.12222222222222222
# Elephant AP: 0.5857945353796414
# mAP = 0.35400837880093183
# 132/243
# Elapsed time = 5.142686128616333
# Owl AP: 0.137037037037037
# Elephant AP: 0.5857945353796414
# mAP = 0.36141578620833925
# 133/243
# Elapsed time = 5.427246809005737
# Owl AP: 0.23283991228070172
# Elephant AP: 0.5857945353796414
# mAP = 0.40931722383017155
# 134/243
# Elapsed time = 5.678432941436768
# Owl AP: 0.25827094474153295
# Elephant AP: 0.5846702977922977
# mAP = 0.42147062126691537
# 135/243
# Elapsed time = 5.417128562927246
# Owl AP: 0.22532312036622382
# Elephant AP: 0.5844359037308456
# mAP = 0.40487951204853473
# 136/243
# Elapsed time = 6.3048741817474365
# Owl AP: 0.20442868335950096
# Elephant AP: 0.5838765914476451
# mAP = 0.39415263740357304
# 137/243
# Elapsed time = 5.80249285697937
# Owl AP: 0.24590747615527922
# Elephant AP: 0.5838765914476451
# mAP = 0.41489203380146217
# 138/243
# Elapsed time = 5.874892711639404
# Owl AP: 0.3593947800110081
# Elephant AP: 0.5838765914476451
# mAP = 0.4716356857293266
# 139/243
# Elapsed time = 5.435449123382568
# Owl AP: 0.4022146013021701
# Elephant AP: 0.5838765914476451
# mAP = 0.49304559637490764
# 140/243
# Elapsed time = 6.48886513710022
# Owl AP: 0.368042068875989
# Elephant AP: 0.5838174971993393
# mAP = 0.47592978303766414
# 141/243
# Elapsed time = 5.330563306808472
# Owl AP: 0.3941122163196632
# Elephant AP: 0.5821255762280094
# mAP = 0.4881188962738363
# 142/243
# Elapsed time = 5.632443904876709
# Owl AP: 0.33758829790777056
# Elephant AP: 0.5815610144449115
# mAP = 0.459574656176341
# 143/243
# Elapsed time = 6.554567098617554
# Owl AP: 0.3945747973952692
# Elephant AP: 0.5815610144449115
# mAP = 0.4880679059200903
# 144/243
# Elapsed time = 6.580666780471802
# Owl AP: 0.41205501543075634
# Elephant AP: 0.5815610144449115
# mAP = 0.4968080149378339
# 145/243
# Elapsed time = 5.446213960647583
# Owl AP: 0.43963455674854846
# Elephant AP: 0.5815610144449115
# mAP = 0.51059778559673
# 146/243
# Elapsed time = 5.928741216659546
# Owl AP: 0.4737284905936332
# Elephant AP: 0.5815610144449115
# mAP = 0.5276447525192723
# 147/243
# Elapsed time = 5.780559778213501
# Owl AP: 0.5123366932311961
# Elephant AP: 0.5815610144449115
# mAP = 0.5469488538380538
# 148/243
# Elapsed time = 5.131040573120117
# Owl AP: 0.5158681237480178
# Elephant AP: 0.5815610144449115
# mAP = 0.5487145690964647
# 149/243
# Elapsed time = 5.109506130218506
# Owl AP: 0.5301521786267057
# Elephant AP: 0.5815610144449115
# mAP = 0.5558565965358087
# 150/243
# Elapsed time = 5.294922351837158
# Owl AP: 0.5325278465968776
# Elephant AP: 0.5815610144449115
# mAP = 0.5570444305208946
# 151/243
# Elapsed time = 5.181674242019653
# Owl AP: 0.5287917978924175
# Elephant AP: 0.5815610144449115
# mAP = 0.5551764061686645
# 152/243
# Elapsed time = 5.078672885894775
# Owl AP: 0.5464426843728782
# Elephant AP: 0.5815610144449115
# mAP = 0.5640018494088949
# 153/243
# Elapsed time = 5.3935534954071045
# Owl AP: 0.5689980679491319
# Elephant AP: 0.5815610144449115
# mAP = 0.5752795411970217
# 154/243
# Elapsed time = 6.005533933639526
# Owl AP: 0.5712426315011374
# Elephant AP: 0.5809613581424667
# mAP = 0.576101994821802
# 155/243
# Elapsed time = 5.812452077865601
# Owl AP: 0.579021232885978
# Elephant AP: 0.5809613581424667
# mAP = 0.5799912955142223
# 156/243
# Elapsed time = 6.226900815963745
# Owl AP: 0.5960989278728928
# Elephant AP: 0.5809613581424667
# mAP = 0.5885301430076797
# 157/243
# Elapsed time = 5.115748167037964
# Owl AP: 0.6048932703447089
# Elephant AP: 0.5809613581424667
# mAP = 0.5929273142435878
# 158/243
# Elapsed time = 5.1411285400390625
# Owl AP: 0.6041648495779242
# Elephant AP: 0.5809613581424667
# mAP = 0.5925631038601955
# 159/243
# Elapsed time = 5.592997074127197
# Owl AP: 0.614683685113563
# Elephant AP: 0.5809613581424667
# mAP = 0.5978225216280149
# 160/243
# Elapsed time = 5.259741306304932
# Owl AP: 0.626599038192074
# Elephant AP: 0.5808921679242941
# mAP = 0.603745603058184
# 161/243
# Elapsed time = 5.5868096351623535
# Owl AP: 0.6054455797208582
# Elephant AP: 0.5808921679242941
# mAP = 0.5931688738225762
# 162/243
# Elapsed time = 5.441660642623901
# Owl AP: 0.6084367270573984
# Elephant AP: 0.5808921679242941
# mAP = 0.5946644474908462
# 163/243
# Elapsed time = 5.279412508010864
# Owl AP: 0.6078587852620719
# Elephant AP: 0.580810849821043
# mAP = 0.5943348175415575
# 164/243
# Elapsed time = 5.847245454788208
# Owl AP: 0.6172822122052446
# Elephant AP: 0.580810849821043
# mAP = 0.5990465310131439
# 165/243
# Elapsed time = 5.265681028366089
# Owl AP: 0.6265746582904337
# Elephant AP: 0.580810849821043
# mAP = 0.6036927540557384
# 166/243
# Elapsed time = 5.674464464187622
# Owl AP: 0.6313939137810048
# Elephant AP: 0.5807272367246658
# mAP = 0.6060605752528353
# 167/243
# Elapsed time = 5.896158695220947
# Owl AP: 0.6326327738664456
# Elephant AP: 0.5806796833842635
# mAP = 0.6066562286253545
# 168/243
# Elapsed time = 5.5716941356658936
# Owl AP: 0.6411429984000747
# Elephant AP: 0.5806796833842635
# mAP = 0.6109113408921691
# 169/243
# Elapsed time = 5.6174187660217285
# Owl AP: 0.6375212549508619
# Elephant AP: 0.5806306769583107
# mAP = 0.6090759659545864
# 170/243
# Elapsed time = 6.576051712036133
# Owl AP: 0.6350191317208093
# Elephant AP: 0.5806306769583107
# mAP = 0.60782490433956
# 171/243
# Elapsed time = 6.072326898574829
# Owl AP: 0.6294606380283039
# Elephant AP: 0.5805853759607966
# mAP = 0.6050230069945502
# 172/243
# Elapsed time = 5.786180257797241
# Owl AP: 0.6106411402252626
# Elephant AP: 0.5805853759607966
# mAP = 0.5956132580930296
# 173/243
# Elapsed time = 5.478924751281738
# Owl AP: 0.6234441476308984
# Elephant AP: 0.5805853759607966
# mAP = 0.6020147617958476
# 174/243
# Elapsed time = 5.4007322788238525
# Owl AP: 0.6319187195547132
# Elephant AP: 0.5805853759607966
# mAP = 0.6062520477577549
# 175/243
# Elapsed time = 5.904808521270752
# Owl AP: 0.6393566135598138
# Elephant AP: 0.5805853759607966
# mAP = 0.6099709947603051
# 176/243
# Elapsed time = 5.346471548080444
# Owl AP: 0.6474630518998871
# Elephant AP: 0.5802202417591464
# mAP = 0.6138416468295167
# 177/243
# Elapsed time = 5.436872959136963
# Owl AP: 0.6463915009811988
# Elephant AP: 0.5801708148374309
# mAP = 0.6132811579093149
# 178/243
# Elapsed time = 5.31420111656189
# Owl AP: 0.6325757731884898
# Elephant AP: 0.5801222991340376
# mAP = 0.6063490361612637
# 179/243
# Elapsed time = 5.572937965393066
# Owl AP: 0.6385410771026053
# Elephant AP: 0.5801222991340376
# mAP = 0.6093316881183215
# 180/243
# Elapsed time = 5.537449836730957
# Owl AP: 0.6391399770727391
# Elephant AP: 0.5800693867775216
# mAP = 0.6096046819251304
# 181/243
# Elapsed time = 6.616692543029785
# Owl AP: 0.6416574357913837
# Elephant AP: 0.5800693867775216
# mAP = 0.6108634112844527
# 182/243
# Elapsed time = 5.340508699417114
# Owl AP: 0.6359275436116097
# Elephant AP: 0.5800693867775216
# mAP = 0.6079984651945657
# 183/243
# Elapsed time = 5.360662460327148
# Owl AP: 0.635419254181263
# Elephant AP: 0.5800693867775216
# mAP = 0.6077443204793923
# 184/243
# Elapsed time = 5.36432409286499
# Owl AP: 0.6277935920094061
# Elephant AP: 0.5795333703310003
# mAP = 0.6036634811702032
# 185/243
# Elapsed time = 5.968854904174805
# Owl AP: 0.634711065297188
# Elephant AP: 0.5795333703310003
# mAP = 0.6071222178140941
# 186/243
# Elapsed time = 5.54524827003479
# Owl AP: 0.6268869195231083
# Elephant AP: 0.5794144170167183
# mAP = 0.6031506682699133
# 187/243
# Elapsed time = 5.7416672706604
# Owl AP: 0.6342645985810704
# Elephant AP: 0.5792706452230797
# mAP = 0.606767621902075
# 188/243
# Elapsed time = 5.734184980392456
# Owl AP: 0.639961771998684
# Elephant AP: 0.5792706452230797
# mAP = 0.6096162086108818
# 189/243
# Elapsed time = 5.444939613342285
# Owl AP: 0.6425269779706988
# Elephant AP: 0.5792706452230797
# mAP = 0.6108988115968892
# 190/243
# Elapsed time = 5.266302585601807
# Owl AP: 0.6516190590068448
# Elephant AP: 0.5792706452230797
# mAP = 0.6154448521149622
# 191/243
# Elapsed time = 5.441395998001099
# Owl AP: 0.6529075963042272
# Elephant AP: 0.579141811846694
# mAP = 0.6160247040754606
# 192/243
# Elapsed time = 5.192071437835693
# Owl AP: 0.6540299183681907
# Elephant AP: 0.579141811846694
# mAP = 0.6165858651074423
# 193/243
# Elapsed time = 5.519444942474365
# Owl AP: 0.6468756333918537
# Elephant AP: 0.5790152332182726
# mAP = 0.6129454333050632
# 194/243
# Elapsed time = 5.627431631088257
# Owl AP: 0.6521136901276495
# Elephant AP: 0.5790152332182726
# mAP = 0.6155644616729611
# 195/243
# Elapsed time = 5.285316228866577
# Owl AP: 0.6567394915239457
# Elephant AP: 0.5790152332182726
# mAP = 0.6178773623711091
# 196/243
# Elapsed time = 5.371176242828369
# Owl AP: 0.6584298741665813
# Elephant AP: 0.5790152332182726
# mAP = 0.618722553692427
# 197/243
# Elapsed time = 5.143117189407349
# Owl AP: 0.6514237567944504
# Elephant AP: 0.5788206900261825
# mAP = 0.6151222234103164
# 198/243
# Elapsed time = 5.2127697467803955
# Owl AP: 0.6584220501113162
# Elephant AP: 0.5788206900261825
# mAP = 0.6186213700687493
# 199/243
# Elapsed time = 5.705004453659058
# Owl AP: 0.651585424659614
# Elephant AP: 0.5783602537580809
# mAP = 0.6149728392088474
# 200/243
# Elapsed time = 5.85860538482666
# Owl AP: 0.6561994701443432
# Elephant AP: 0.5781183495577811
# mAP = 0.6171589098510621
# 201/243
# Elapsed time = 5.446457147598267
# Owl AP: 0.656298807169424
# Elephant AP: 0.5781183495577811
# mAP = 0.6172085783636025
# 202/243
# Elapsed time = 5.427921533584595
# Owl AP: 0.6580683585670098
# Elephant AP: 0.5781183495577811
# mAP = 0.6180933540623954
# 203/243
# Elapsed time = 5.391274690628052
# Owl AP: 0.6610605987919392
# Elephant AP: 0.5781183495577811
# mAP = 0.6195894741748602
# 204/243
# Elapsed time = 5.579325437545776
# Owl AP: 0.6650876687131487
# Elephant AP: 0.5781183495577811
# mAP = 0.621603009135465
# 205/243
# Elapsed time = 5.1439549922943115
# Owl AP: 0.6594665284535822
# Elephant AP: 0.5780758823376019
# mAP = 0.618771205395592
# 206/243
# Elapsed time = 5.278173923492432
# Owl AP: 0.6620314500686205
# Elephant AP: 0.5780758823376019
# mAP = 0.6200536662031112
# 207/243
# Elapsed time = 5.233206510543823
# Owl AP: 0.6661231471718018
# Elephant AP: 0.5779307921062394
# mAP = 0.6220269696390206
# 208/243
# Elapsed time = 5.314953327178955
# Owl AP: 0.6700921526323694
# Elephant AP: 0.5779307921062394
# mAP = 0.6240114723693044
# 209/243
# Elapsed time = 5.503846168518066
# Owl AP: 0.6669875985593897
# Elephant AP: 0.5779307921062394
# mAP = 0.6224591953328146
# 210/243
# Elapsed time = 5.671155214309692
# Owl AP: 0.6609516679573993
# Elephant AP: 0.5779307921062394
# mAP = 0.6194412300318194
# 211/243
# Elapsed time = 5.608198642730713
# Owl AP: 0.6566973663196481
# Elephant AP: 0.5779307921062394
# mAP = 0.6173140792129438
# 212/243
# Elapsed time = 5.322974681854248
# Owl AP: 0.6601273314901297
# Elephant AP: 0.5779307921062394
# mAP = 0.6190290617981846
# 213/243
# Elapsed time = 5.1973183155059814
# Owl AP: 0.652936703899519
# Elephant AP: 0.5778393790665459
# mAP = 0.6153880414830324
# 214/243
# Elapsed time = 5.25748610496521
# Owl AP: 0.6543299520279541
# Elephant AP: 0.5778393790665459
# mAP = 0.61608466554725
# 215/243
# Elapsed time = 5.0261805057525635
# Owl AP: 0.6504976152060646
# Elephant AP: 0.5778393790665459
# mAP = 0.6141684971363053
# 216/243
# Elapsed time = 5.343938827514648
# Owl AP: 0.6321265451993671
# Elephant AP: 0.5776425327635802
# mAP = 0.6048845389814737
# 217/243
# Elapsed time = 5.365063667297363
# Owl AP: 0.635556767539251
# Elephant AP: 0.5776425327635802
# mAP = 0.6065996501514157
# 218/243
# Elapsed time = 5.109347820281982
# Owl AP: 0.6389431663366637
# Elephant AP: 0.5776425327635802
# mAP = 0.608292849550122
# 219/243
# Elapsed time = 5.440479278564453
# Owl AP: 0.6452219548676552
# Elephant AP: 0.5776425327635802
# mAP = 0.6114322438156177
# 220/243
# Elapsed time = 5.448824644088745
# Owl AP: 0.6491190215573247
# Elephant AP: 0.5776425327635802
# mAP = 0.6133807771604525
# 221/243
# Elapsed time = 5.417039632797241
# Owl AP: 0.6519508631732142
# Elephant AP: 0.5776425327635802
# mAP = 0.6147966979683972
# 222/243
# Elapsed time = 5.3014726638793945
# Owl AP: 0.6571603715125494
# Elephant AP: 0.5776425327635802
# mAP = 0.6174014521380649
# 223/243
# Elapsed time = 5.1791603565216064
# Owl AP: 0.6598357445240614
# Elephant AP: 0.5776425327635802
# mAP = 0.6187391386438208
# 224/243
# Elapsed time = 8.502593040466309
# Owl AP: 0.6639773797451084
# Elephant AP: 0.5776425327635802
# mAP = 0.6208099562543443
# 225/243
# Elapsed time = 13.116851806640625
# Owl AP: 0.6673305245169199
# Elephant AP: 0.5776425327635802
# mAP = 0.6224865286402501
# 226/243
# Elapsed time = 5.473569393157959
# Owl AP: 0.6557468324773719
# Elephant AP: 0.5776425327635802
# mAP = 0.616694682620476
# 227/243
# Elapsed time = 5.334203243255615
# Owl AP: 0.6597044565215171
# Elephant AP: 0.577017400689682
# mAP = 0.6183609286055995
# 228/243
# Elapsed time = 5.927191257476807
# Owl AP: 0.6503804678529399
# Elephant AP: 0.577017400689682
# mAP = 0.613698934271311
# 229/243
# Elapsed time = 5.321058750152588
# Owl AP: 0.6520431544355995
# Elephant AP: 0.577017400689682
# mAP = 0.6145302775626407
# 230/243
# Elapsed time = 6.603912830352783
# Owl AP: 0.6422547049828307
# Elephant AP: 0.577017400689682
# mAP = 0.6096360528362563
# 231/243
# Elapsed time = 5.432469606399536
# Owl AP: 0.6448633274363192
# Elephant AP: 0.577017400689682
# mAP = 0.6109403640630007
# 232/243
# Elapsed time = 5.692124128341675
# Owl AP: 0.6499586959841432
# Elephant AP: 0.577017400689682
# mAP = 0.6134880483369126
# 233/243
# Elapsed time = 5.094354152679443
# Owl AP: 0.650423509304342
# Elephant AP: 0.577017400689682
# mAP = 0.613720454997012
# 234/243
# Elapsed time = 5.349873065948486
# Owl AP: 0.6455669367934438
# Elephant AP: 0.5768783496881041
# mAP = 0.6112226432407739
# 235/243
# Elapsed time = 5.394272565841675
# Owl AP: 0.6412278442948942
# Elephant AP: 0.5768783496881041
# mAP = 0.6090530969914991
# 236/243
# Elapsed time = 5.9075000286102295
# Owl AP: 0.6430288708569788
# Elephant AP: 0.5768783496881041
# mAP = 0.6099536102725415
# 237/243
# Elapsed time = 5.084804058074951
# Owl AP: 0.6434956830789157
# Elephant AP: 0.5765655835130818
# mAP = 0.6100306332959988
# 238/243
# Elapsed time = 5.306699514389038
# Owl AP: 0.6395762908346866
# Elephant AP: 0.5764684971151978
# mAP = 0.6080223939749422
# 239/243
# Elapsed time = 5.284148693084717
# Owl AP: 0.6443286837732697
# Elephant AP: 0.5764684971151978
# mAP = 0.6103985904442337
# 240/243
# Elapsed time = 7.15040922164917
# Owl AP: 0.6442417412475837
# Elephant AP: 0.5764684971151978
# mAP = 0.6103551191813907
# 241/243
# Elapsed time = 5.3818652629852295
# Owl AP: 0.6397866396869859
# Elephant AP: 0.5764684971151978
# mAP = 0.6081275684010918
# 242/243
# Elapsed time = 5.443021774291992
# Owl AP: 0.6410574345120315
# Elephant AP: 0.5764684971151978
# mAP = 0.6087629658136147
#
# mean average precision: nan

# %%
mAP = [mAP for mAP in mAPs if str(mAP)!='nan']
mean_average_prec = round(np.mean(np.array(mAP)), 3)
print('After training %dk batches, the mean average precision is %0.3f'%(len(record_df), mean_average_prec))

# record_df.loc[len(record_df)-1, 'mAP'] = mean_average_prec
# record_df.to_csv(C.record_path, index=0)
# print('Save mAP to {}'.format(C.record_path))
# Out:
# After training 1099k batches, the mean average precision is 0.582

# %% [markdown]
# #VIDEO

# %% [markdown]
# **SE CREAN LAS CARPETAS PARA GUARDAR LAS IMAGENES, UNA PARA IMAGENES DEL VIDEO Y OTRA PARA IMAGENES QUE YA FUERON PREDICHAS Y QUE SON PARA GENERAR EL NUEVO VIDEO**

# %%
# !mkdir -p "/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video"
# !mkdir -p "/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred"

# %% [markdown]
# **CAPTURAMOS LAS IMAGENES QUE SE GENERAN DEL VIDEO Y SE GUARDAN EN LA CARPETA CREADA**

# %%
#PROCESAMIENTO DEL VIDEO
# caprturar el video y procesarlo frame a frame, esto  procesa cada imagen y las guarda en un archivo en drive dispuesto por usted.
cap = cv2.VideoCapture('/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/owl_test.mp4') #Cargue aqui el video
frame_count = 0
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720) #Usted puede decidir cambiar el alto
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280) #Tambien el ancho

while True:
  ret, frame = cap.read()
  if not ret:
    break
  frame_count += 1
  print('Numero de frames : {0}'.format(frame_count))
  
  #results = model_rpn.detect([frame], verbose=0) #Esta linea debe ser interpretada y arreglada por ustedes dado que es el modelo qu ustedes entrenaron y va a detectar.

  #r = results[0] #Que info trae r en el caso de FasterRCNN???
  
  fname= '{0}.jpg'.format(frame_count)
  fname = os.path.join('/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video',fname) #Crea la ruta donde ira cada imagen procesada.
  cv2.imwrite(fname, frame) #Escribe cada imagen a disco
  print('El archivo fue escrito en :{0}',format(fname))
cap.release()

#Nota: Los nombres de las imagenes procesadas seran numeros ordenados, de tal manera que puedan ser procesados facilmente a continuacion y crear un video a partir de los frames.
# Out:
# Numero de frames : 1
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/1.jpg
# Numero de frames : 2
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/2.jpg
# Numero de frames : 3
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/3.jpg
# Numero de frames : 4
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/4.jpg
# Numero de frames : 5
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/5.jpg
# Numero de frames : 6
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/6.jpg
# Numero de frames : 7
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/7.jpg
# Numero de frames : 8
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/8.jpg
# Numero de frames : 9
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/9.jpg
# Numero de frames : 10
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/10.jpg
# Numero de frames : 11
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/11.jpg
# Numero de frames : 12
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/12.jpg
# Numero de frames : 13
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/13.jpg
# Numero de frames : 14
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/14.jpg
# Numero de frames : 15
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/15.jpg
# Numero de frames : 16
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/16.jpg
# Numero de frames : 17
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/17.jpg
# Numero de frames : 18
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/18.jpg
# Numero de frames : 19
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/19.jpg
# Numero de frames : 20
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/20.jpg
# Numero de frames : 21
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/21.jpg
# Numero de frames : 22
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/22.jpg
# Numero de frames : 23
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/23.jpg
# Numero de frames : 24
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/24.jpg
# Numero de frames : 25
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/25.jpg
# Numero de frames : 26
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/26.jpg
# Numero de frames : 27
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/27.jpg
# Numero de frames : 28
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/28.jpg
# Numero de frames : 29
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/29.jpg
# Numero de frames : 30
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/30.jpg
# Numero de frames : 31
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/31.jpg
# Numero de frames : 32
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/32.jpg
# Numero de frames : 33
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/33.jpg
# Numero de frames : 34
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/34.jpg
# Numero de frames : 35
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/35.jpg
# Numero de frames : 36
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/36.jpg
# Numero de frames : 37
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/37.jpg
# Numero de frames : 38
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/38.jpg
# Numero de frames : 39
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/39.jpg
# Numero de frames : 40
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/40.jpg
# Numero de frames : 41
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/41.jpg
# Numero de frames : 42
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/42.jpg
# Numero de frames : 43
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/43.jpg
# Numero de frames : 44
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/44.jpg
# Numero de frames : 45
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/45.jpg
# Numero de frames : 46
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/46.jpg
# Numero de frames : 47
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/47.jpg
# Numero de frames : 48
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/48.jpg
# Numero de frames : 49
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/49.jpg
# Numero de frames : 50
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/50.jpg
# Numero de frames : 51
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/51.jpg
# Numero de frames : 52
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/52.jpg
# Numero de frames : 53
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/53.jpg
# Numero de frames : 54
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/54.jpg
# Numero de frames : 55
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/55.jpg
# Numero de frames : 56
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/56.jpg
# Numero de frames : 57
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/57.jpg
# Numero de frames : 58
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/58.jpg
# Numero de frames : 59
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/59.jpg
# Numero de frames : 60
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/60.jpg
# Numero de frames : 61
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/61.jpg
# Numero de frames : 62
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/62.jpg
# Numero de frames : 63
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/63.jpg
# Numero de frames : 64
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/64.jpg
# Numero de frames : 65
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/65.jpg
# Numero de frames : 66
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/66.jpg
# Numero de frames : 67
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/67.jpg
# Numero de frames : 68
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/68.jpg
# Numero de frames : 69
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/69.jpg
# Numero de frames : 70
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/70.jpg
# Numero de frames : 71
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/71.jpg
# Numero de frames : 72
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/72.jpg
# Numero de frames : 73
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/73.jpg
# Numero de frames : 74
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/74.jpg
# Numero de frames : 75
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/75.jpg
# Numero de frames : 76
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/76.jpg
# Numero de frames : 77
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/77.jpg
# Numero de frames : 78
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/78.jpg
# Numero de frames : 79
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/79.jpg
# Numero de frames : 80
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/80.jpg
# Numero de frames : 81
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/81.jpg
# Numero de frames : 82
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/82.jpg
# Numero de frames : 83
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/83.jpg
# Numero de frames : 84
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/84.jpg
# Numero de frames : 85
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/85.jpg
# Numero de frames : 86
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/86.jpg
# Numero de frames : 87
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/87.jpg
# Numero de frames : 88
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/88.jpg
# Numero de frames : 89
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/89.jpg
# Numero de frames : 90
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/90.jpg
# Numero de frames : 91
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/91.jpg
# Numero de frames : 92
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/92.jpg
# Numero de frames : 93
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/93.jpg
# Numero de frames : 94
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/94.jpg
# Numero de frames : 95
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/95.jpg
# Numero de frames : 96
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/96.jpg
# Numero de frames : 97
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/97.jpg
# Numero de frames : 98
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/98.jpg
# Numero de frames : 99
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/99.jpg
# Numero de frames : 100
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/100.jpg
# Numero de frames : 101
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/101.jpg
# Numero de frames : 102
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/102.jpg
# Numero de frames : 103
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/103.jpg
# Numero de frames : 104
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/104.jpg
# Numero de frames : 105
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/105.jpg
# Numero de frames : 106
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/106.jpg
# Numero de frames : 107
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/107.jpg
# Numero de frames : 108
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/108.jpg
# Numero de frames : 109
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/109.jpg
# Numero de frames : 110
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/110.jpg
# Numero de frames : 111
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/111.jpg
# Numero de frames : 112
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/112.jpg
# Numero de frames : 113
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/113.jpg
# Numero de frames : 114
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/114.jpg
# Numero de frames : 115
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/115.jpg
# Numero de frames : 116
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/116.jpg
# Numero de frames : 117
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/117.jpg
# Numero de frames : 118
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/118.jpg
# Numero de frames : 119
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/119.jpg
# Numero de frames : 120
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/120.jpg
# Numero de frames : 121
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/121.jpg
# Numero de frames : 122
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/122.jpg
# Numero de frames : 123
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/123.jpg
# Numero de frames : 124
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/124.jpg
# Numero de frames : 125
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/125.jpg
# Numero de frames : 126
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/126.jpg
# Numero de frames : 127
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/127.jpg
# Numero de frames : 128
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/128.jpg
# Numero de frames : 129
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/129.jpg
# Numero de frames : 130
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/130.jpg
# Numero de frames : 131
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/131.jpg
# Numero de frames : 132
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/132.jpg
# Numero de frames : 133
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/133.jpg
# Numero de frames : 134
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/134.jpg
# Numero de frames : 135
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/135.jpg
# Numero de frames : 136
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/136.jpg
# Numero de frames : 137
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/137.jpg
# Numero de frames : 138
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/138.jpg
# Numero de frames : 139
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/139.jpg
# Numero de frames : 140
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/140.jpg
# Numero de frames : 141
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/141.jpg
# Numero de frames : 142
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/142.jpg
# Numero de frames : 143
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/143.jpg
# Numero de frames : 144
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/144.jpg
# Numero de frames : 145
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/145.jpg
# Numero de frames : 146
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/146.jpg
# Numero de frames : 147
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/147.jpg
# Numero de frames : 148
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/148.jpg
# Numero de frames : 149
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/149.jpg
# Numero de frames : 150
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/150.jpg
# Numero de frames : 151
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/151.jpg
# Numero de frames : 152
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/152.jpg
# Numero de frames : 153
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/153.jpg
# Numero de frames : 154
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/154.jpg
# Numero de frames : 155
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/155.jpg
# Numero de frames : 156
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/156.jpg
# Numero de frames : 157
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/157.jpg
# Numero de frames : 158
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/158.jpg
# Numero de frames : 159
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/159.jpg
# Numero de frames : 160
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/160.jpg
# Numero de frames : 161
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/161.jpg
# Numero de frames : 162
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/162.jpg
# Numero de frames : 163
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/163.jpg
# Numero de frames : 164
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/164.jpg
# Numero de frames : 165
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/165.jpg
# Numero de frames : 166
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/166.jpg
# Numero de frames : 167
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/167.jpg
# Numero de frames : 168
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/168.jpg
# Numero de frames : 169
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/169.jpg
# Numero de frames : 170
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/170.jpg
# Numero de frames : 171
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/171.jpg
# Numero de frames : 172
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/172.jpg
# Numero de frames : 173
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/173.jpg
# Numero de frames : 174
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/174.jpg
# Numero de frames : 175
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/175.jpg
# Numero de frames : 176
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/176.jpg
# Numero de frames : 177
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/177.jpg
# Numero de frames : 178
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/178.jpg
# Numero de frames : 179
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/179.jpg
# Numero de frames : 180
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/180.jpg
# Numero de frames : 181
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/181.jpg
# Numero de frames : 182
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/182.jpg
# Numero de frames : 183
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/183.jpg
# Numero de frames : 184
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/184.jpg
# Numero de frames : 185
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/185.jpg
# Numero de frames : 186
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/186.jpg
# Numero de frames : 187
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/187.jpg
# Numero de frames : 188
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/188.jpg
# Numero de frames : 189
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/189.jpg
# Numero de frames : 190
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/190.jpg
# Numero de frames : 191
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/191.jpg
# Numero de frames : 192
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/192.jpg
# Numero de frames : 193
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/193.jpg
# Numero de frames : 194
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/194.jpg
# Numero de frames : 195
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/195.jpg
# Numero de frames : 196
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/196.jpg
# Numero de frames : 197
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/197.jpg
# Numero de frames : 198
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/198.jpg
# Numero de frames : 199
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/199.jpg
# Numero de frames : 200
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/200.jpg
# Numero de frames : 201
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/201.jpg
# Numero de frames : 202
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/202.jpg
# Numero de frames : 203
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/203.jpg
# Numero de frames : 204
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/204.jpg
# Numero de frames : 205
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/205.jpg
# Numero de frames : 206
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/206.jpg
# Numero de frames : 207
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/207.jpg
# Numero de frames : 208
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/208.jpg
# Numero de frames : 209
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/209.jpg
# Numero de frames : 210
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/210.jpg
# Numero de frames : 211
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/211.jpg
# Numero de frames : 212
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/212.jpg
# Numero de frames : 213
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/213.jpg
# Numero de frames : 214
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/214.jpg
# Numero de frames : 215
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/215.jpg
# Numero de frames : 216
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/216.jpg
# Numero de frames : 217
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/217.jpg
# Numero de frames : 218
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/218.jpg
# Numero de frames : 219
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/219.jpg
# Numero de frames : 220
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/220.jpg
# Numero de frames : 221
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/221.jpg
# Numero de frames : 222
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/222.jpg
# Numero de frames : 223
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/223.jpg
# Numero de frames : 224
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/224.jpg
# Numero de frames : 225
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/225.jpg
# Numero de frames : 226
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/226.jpg
# Numero de frames : 227
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/227.jpg
# Numero de frames : 228
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/228.jpg
# Numero de frames : 229
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/229.jpg
# Numero de frames : 230
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/230.jpg
# Numero de frames : 231
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/231.jpg
# Numero de frames : 232
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/232.jpg
# Numero de frames : 233
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/233.jpg
# Numero de frames : 234
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/234.jpg
# Numero de frames : 235
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/235.jpg
# Numero de frames : 236
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/236.jpg
# Numero de frames : 237
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/237.jpg
# Numero de frames : 238
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/238.jpg
# Numero de frames : 239
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/239.jpg
# Numero de frames : 240
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/240.jpg
# Numero de frames : 241
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/241.jpg
# Numero de frames : 242
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/242.jpg
# Numero de frames : 243
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/243.jpg
# Numero de frames : 244
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/244.jpg
# Numero de frames : 245
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/245.jpg
# Numero de frames : 246
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/246.jpg
# Numero de frames : 247
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/247.jpg
# Numero de frames : 248
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/248.jpg
# Numero de frames : 249
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/249.jpg
# Numero de frames : 250
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/250.jpg
# Numero de frames : 251
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/251.jpg
# Numero de frames : 252
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/252.jpg
# Numero de frames : 253
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/253.jpg
# Numero de frames : 254
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/254.jpg
# Numero de frames : 255
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/255.jpg
# Numero de frames : 256
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/256.jpg
# Numero de frames : 257
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/257.jpg
# Numero de frames : 258
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/258.jpg
# Numero de frames : 259
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/259.jpg
# Numero de frames : 260
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/260.jpg
# Numero de frames : 261
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/261.jpg
# Numero de frames : 262
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/262.jpg
# Numero de frames : 263
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/263.jpg
# Numero de frames : 264
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/264.jpg
# Numero de frames : 265
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/265.jpg
# Numero de frames : 266
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/266.jpg
# Numero de frames : 267
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/267.jpg
# Numero de frames : 268
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/268.jpg
# Numero de frames : 269
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/269.jpg
# Numero de frames : 270
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/270.jpg
# Numero de frames : 271
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/271.jpg
# Numero de frames : 272
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/272.jpg
# Numero de frames : 273
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/273.jpg
# Numero de frames : 274
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/274.jpg
# Numero de frames : 275
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/275.jpg
# Numero de frames : 276
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/276.jpg
# Numero de frames : 277
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/277.jpg
# Numero de frames : 278
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/278.jpg
# Numero de frames : 279
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/279.jpg
# Numero de frames : 280
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/280.jpg
# Numero de frames : 281
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/281.jpg
# Numero de frames : 282
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/282.jpg
# Numero de frames : 283
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/283.jpg
# Numero de frames : 284
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/284.jpg
# Numero de frames : 285
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/285.jpg
# Numero de frames : 286
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/286.jpg
# Numero de frames : 287
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/287.jpg
# Numero de frames : 288
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/288.jpg
# Numero de frames : 289
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/289.jpg
# Numero de frames : 290
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/290.jpg
# Numero de frames : 291
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/291.jpg
# Numero de frames : 292
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/292.jpg
# Numero de frames : 293
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/293.jpg
# Numero de frames : 294
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/294.jpg
# Numero de frames : 295
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/295.jpg
# Numero de frames : 296
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/296.jpg
# Numero de frames : 297
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/297.jpg
# Numero de frames : 298
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/298.jpg
# Numero de frames : 299
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/299.jpg
# Numero de frames : 300
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/300.jpg
# Numero de frames : 301
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/301.jpg
# Numero de frames : 302
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/302.jpg
# Numero de frames : 303
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/303.jpg
# Numero de frames : 304
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/304.jpg
# Numero de frames : 305
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/305.jpg
# Numero de frames : 306
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/306.jpg
# Numero de frames : 307
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/307.jpg
# Numero de frames : 308
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/308.jpg
# Numero de frames : 309
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/309.jpg
# Numero de frames : 310
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/310.jpg
# Numero de frames : 311
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/311.jpg
# Numero de frames : 312
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/312.jpg
# Numero de frames : 313
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/313.jpg
# Numero de frames : 314
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/314.jpg
# Numero de frames : 315
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/315.jpg
# Numero de frames : 316
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/316.jpg
# Numero de frames : 317
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/317.jpg
# Numero de frames : 318
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/318.jpg
# Numero de frames : 319
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/319.jpg
# Numero de frames : 320
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/320.jpg
# Numero de frames : 321
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/321.jpg
# Numero de frames : 322
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/322.jpg
# Numero de frames : 323
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/323.jpg
# Numero de frames : 324
# ...
# Numero de frames : 421
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/421.jpg
# Numero de frames : 422
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/422.jpg
# Numero de frames : 423
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/423.jpg
# Numero de frames : 424
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/424.jpg
# Numero de frames : 425
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/425.jpg
# Numero de frames : 426
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/426.jpg
# Numero de frames : 427
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/427.jpg
# Numero de frames : 428
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/428.jpg
# Numero de frames : 429
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/429.jpg
# Numero de frames : 430
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/430.jpg
# Numero de frames : 431
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/431.jpg
# Numero de frames : 432
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/432.jpg
# Numero de frames : 433
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/433.jpg
# Numero de frames : 434
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/434.jpg
# Numero de frames : 435
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/435.jpg
# Numero de frames : 436
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/436.jpg
# Numero de frames : 437
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/437.jpg
# Numero de frames : 438
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/438.jpg
# Numero de frames : 439
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/439.jpg
# Numero de frames : 440
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/440.jpg
# Numero de frames : 441
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/441.jpg
# Numero de frames : 442
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/442.jpg
# Numero de frames : 443
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/443.jpg
# Numero de frames : 444
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/444.jpg
# Numero de frames : 445
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/445.jpg
# Numero de frames : 446
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/446.jpg
# Numero de frames : 447
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/447.jpg
# Numero de frames : 448
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/448.jpg
# Numero de frames : 449
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/449.jpg
# Numero de frames : 450
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/450.jpg
# Numero de frames : 451
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/451.jpg
# Numero de frames : 452
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/452.jpg
# Numero de frames : 453
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/453.jpg
# Numero de frames : 454
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/454.jpg
# Numero de frames : 455
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/455.jpg
# Numero de frames : 456
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/456.jpg
# Numero de frames : 457
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/457.jpg
# Numero de frames : 458
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/458.jpg
# Numero de frames : 459
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/459.jpg
# Numero de frames : 460
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/460.jpg
# Numero de frames : 461
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/461.jpg
# Numero de frames : 462
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/462.jpg
# Numero de frames : 463
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/463.jpg
# Numero de frames : 464
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/464.jpg
# Numero de frames : 465
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/465.jpg
# Numero de frames : 466
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/466.jpg
# Numero de frames : 467
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/467.jpg
# Numero de frames : 468
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/468.jpg
# Numero de frames : 469
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/469.jpg
# Numero de frames : 470
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/470.jpg
# Numero de frames : 471
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/471.jpg
# Numero de frames : 472
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/472.jpg
# Numero de frames : 473
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/473.jpg
# Numero de frames : 474
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/474.jpg
# Numero de frames : 475
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/475.jpg
# Numero de frames : 476
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/476.jpg
# Numero de frames : 477
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/477.jpg
# Numero de frames : 478
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/478.jpg
# Numero de frames : 479
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/479.jpg
# Numero de frames : 480
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/480.jpg
# Numero de frames : 481
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/481.jpg
# Numero de frames : 482
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/482.jpg
# Numero de frames : 483
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/483.jpg
# Numero de frames : 484
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/484.jpg
# Numero de frames : 485
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/485.jpg
# Numero de frames : 486
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/486.jpg
# Numero de frames : 487
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/487.jpg
# Numero de frames : 488
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/488.jpg
# Numero de frames : 489
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/489.jpg
# Numero de frames : 490
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/490.jpg
# Numero de frames : 491
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/491.jpg
# Numero de frames : 492
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/492.jpg
# Numero de frames : 493
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/493.jpg
# Numero de frames : 494
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/494.jpg
# Numero de frames : 495
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/495.jpg
# Numero de frames : 496
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/496.jpg
# Numero de frames : 497
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/497.jpg
# Numero de frames : 498
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/498.jpg
# Numero de frames : 499
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/499.jpg
# Numero de frames : 500
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/500.jpg
# Numero de frames : 501
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/501.jpg
# Numero de frames : 502
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/502.jpg
# Numero de frames : 503
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/503.jpg
# Numero de frames : 504
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/504.jpg
# Numero de frames : 505
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/505.jpg
# Numero de frames : 506
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/506.jpg
# Numero de frames : 507
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/507.jpg
# Numero de frames : 508
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/508.jpg
# Numero de frames : 509
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/509.jpg
# Numero de frames : 510
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/510.jpg
# Numero de frames : 511
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/511.jpg
# Numero de frames : 512
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/512.jpg
# Numero de frames : 513
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/513.jpg
# Numero de frames : 514
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/514.jpg
# Numero de frames : 515
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/515.jpg
# Numero de frames : 516
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/516.jpg
# Numero de frames : 517
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/517.jpg
# Numero de frames : 518
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/518.jpg
# Numero de frames : 519
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/519.jpg
# Numero de frames : 520
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/520.jpg
# Numero de frames : 521
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/521.jpg
# Numero de frames : 522
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/522.jpg
# Numero de frames : 523
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/523.jpg
# Numero de frames : 524
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/524.jpg
# Numero de frames : 525
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/525.jpg
# Numero de frames : 526
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/526.jpg
# Numero de frames : 527
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video/527.jpg

# %% [markdown]
# **HACEMOS QUE LA VARIABLE imgs_path CONTENGA TODAS LAS IMAGENES QUE SE GUARDARON DEL VIDEO**

# %%
test_base_path = '/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video'

test_imgs = os.listdir(test_base_path)

imgs_path = []
for i in range(0, len(test_imgs), 1):
	imgs_path.append(test_imgs[i])

all_imgs = []

classes = {}

# %%
print(len(test_imgs))
print(len(imgs_path))
# Out:
# 527
# 527

# %% [markdown]
# **SE PREDICEN LAS IMAGENES DEL VIDEO Y SE GUARDAN EN LA CARPETA QUE SE CREO ANTERIORMENTE**

# %%
# If the box classification value is less than this, we ignore this box
bbox_threshold = 0.7
frame_count = 0

for idx, img_name in enumerate(imgs_path):
    if not img_name.lower().endswith(('.bmp', '.jpeg', '.jpg', '.png', '.tif', '.tiff')):
        continue
    print(img_name, ' / ', len(imgs_path))
    st = time.time()
    filepath = os.path.join(test_base_path, img_name)

    img = cv2.imread(filepath)

    X, ratio = format_img(img, C)
    
    X = np.transpose(X, (0, 2, 3, 1))

    # get output layer Y1, Y2 from the RPN and the feature maps F
    # Y1: y_rpn_cls
    # Y2: y_rpn_regr
    [Y1, Y2, F] = model_rpn.predict(X)

    # Get bboxes by applying NMS 
    # R.shape = (300, 4)
    #R = rpn_to_roi(Y1, Y2, C, K.image_dim_ordering(), overlap_thresh=0.7)
    R = rpn_to_roi(Y1, Y2, C, K.image_data_format(), overlap_thresh=0.7)

    # convert from (x1,y1,x2,y2) to (x,y,w,h)
    R[:, 2] -= R[:, 0]
    R[:, 3] -= R[:, 1]

    # apply the spatial pyramid pooling to the proposed regions
    bboxes = {}
    probs = {}

    for jk in range(R.shape[0]//C.num_rois + 1):
        ROIs = np.expand_dims(R[C.num_rois*jk:C.num_rois*(jk+1), :], axis=0)
        if ROIs.shape[1] == 0:
            break

        if jk == R.shape[0]//C.num_rois:
            #pad R
            curr_shape = ROIs.shape
            target_shape = (curr_shape[0],C.num_rois,curr_shape[2])
            ROIs_padded = np.zeros(target_shape).astype(ROIs.dtype)
            ROIs_padded[:, :curr_shape[1], :] = ROIs
            ROIs_padded[0, curr_shape[1]:, :] = ROIs[0, 0, :]
            ROIs = ROIs_padded

        [P_cls, P_regr] = model_classifier_only.predict([F, ROIs])

        # Calculate bboxes coordinates on resized image
        for ii in range(P_cls.shape[1]):
            # Ignore 'bg' class
            if np.max(P_cls[0, ii, :]) < bbox_threshold or np.argmax(P_cls[0, ii, :]) == (P_cls.shape[2] - 1):
                continue

            cls_name = class_mapping[np.argmax(P_cls[0, ii, :])]

            if cls_name not in bboxes:
                bboxes[cls_name] = []
                probs[cls_name] = []

            (x, y, w, h) = ROIs[0, ii, :]

            cls_num = np.argmax(P_cls[0, ii, :])
            try:
                (tx, ty, tw, th) = P_regr[0, ii, 4*cls_num:4*(cls_num+1)]
                tx /= C.classifier_regr_std[0]
                ty /= C.classifier_regr_std[1]
                tw /= C.classifier_regr_std[2]
                th /= C.classifier_regr_std[3]
                x, y, w, h = apply_regr(x, y, w, h, tx, ty, tw, th)
            except:
                pass
            bboxes[cls_name].append([C.rpn_stride*x, C.rpn_stride*y, C.rpn_stride*(x+w), C.rpn_stride*(y+h)])
            probs[cls_name].append(np.max(P_cls[0, ii, :]))

    all_dets = []

    for key in bboxes:
        bbox = np.array(bboxes[key])

        new_boxes, new_probs = non_max_suppression_fast(bbox, np.array(probs[key]), overlap_thresh=0.2)
        for jk in range(new_boxes.shape[0]):
            (x1, y1, x2, y2) = new_boxes[jk,:]

            # Calculate real coordinates on original image
            (real_x1, real_y1, real_x2, real_y2) = get_real_coordinates(ratio, x1, y1, x2, y2)

            cv2.rectangle(img,(real_x1, real_y1), (real_x2, real_y2), (int(class_to_color[key][0]), int(class_to_color[key][1]), int(class_to_color[key][2])),4)

            textLabel = '{}: {}'.format(key,int(100*new_probs[jk]))
            all_dets.append((key,100*new_probs[jk]))

            (retval,baseLine) = cv2.getTextSize(textLabel,cv2.FONT_HERSHEY_COMPLEX,1,1)
            textOrg = (real_x1, real_y1-0)

            cv2.rectangle(img, (textOrg[0] - 5, textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (0, 0, 0), 1)
            cv2.rectangle(img, (textOrg[0] - 5,textOrg[1]+baseLine - 5), (textOrg[0]+retval[0] + 5, textOrg[1]-retval[1] - 5), (255, 255, 255), -1)
            cv2.putText(img, textLabel, textOrg, cv2.FONT_HERSHEY_DUPLEX, 1, (0, 0, 0), 1)

    print('Elapsed time = {}'.format(time.time() - st))
    print(all_dets)

    frame_count += 1
    fname= '{0}.jpg'.format(frame_count)
    fname = os.path.join('/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred',fname) #Crea la ruta donde ira cada imagen procesada.
    cv2.imwrite(fname, img) #Escribe cada imagen a disco
    print('El archivo fue escrito en :{0}',format(fname))
    #plt.figure(figsize=(10,10))
    #plt.grid()
    #plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    #plt.show()
# Out:
# 1.jpg  /  527
# Elapsed time = 6.0241265296936035
# [('Owl', 99.33364391326904), ('Owl', 98.81677031517029), ('Owl', 94.56653594970703), ('Owl', 83.40204954147339)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/1.jpg
# 2.jpg  /  527
# Elapsed time = 5.9342358112335205
# [('Owl', 99.33090209960938), ('Owl', 98.81961345672607), ('Owl', 94.70115900039673), ('Owl', 83.06267857551575)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/2.jpg
# 3.jpg  /  527
# Elapsed time = 5.745391845703125
# [('Owl', 99.38404560089111), ('Owl', 98.95791411399841), ('Owl', 95.10631561279297), ('Owl', 84.54674482345581)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/3.jpg
# 4.jpg  /  527
# Elapsed time = 5.6105310916900635
# [('Owl', 99.22682642936707), ('Owl', 98.9988386631012), ('Owl', 87.68553733825684)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/4.jpg
# 5.jpg  /  527
# Elapsed time = 5.424694061279297
# [('Owl', 99.23175573348999), ('Owl', 99.14262294769287), ('Owl', 90.14168977737427)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/5.jpg
# 6.jpg  /  527
# Elapsed time = 6.39692497253418
# [('Owl', 99.275803565979), ('Owl', 98.58387112617493), ('Owl', 87.85313963890076)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/6.jpg
# 7.jpg  /  527
# Elapsed time = 5.6572465896606445
# [('Owl', 99.3556559085846), ('Owl', 98.49339723587036), ('Owl', 94.46160197257996)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/7.jpg
# 8.jpg  /  527
# Elapsed time = 5.531890392303467
# [('Owl', 99.33152794837952), ('Owl', 97.96603322029114), ('Owl', 72.72825837135315), ('Owl', 71.82491421699524)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/8.jpg
# 9.jpg  /  527
# Elapsed time = 5.628612518310547
# [('Owl', 99.46168065071106), ('Owl', 98.97202849388123), ('Owl', 87.64113187789917)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/9.jpg
# 10.jpg  /  527
# Elapsed time = 5.582868337631226
# [('Owl', 99.3389368057251), ('Owl', 99.02087450027466)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/10.jpg
# 11.jpg  /  527
# Elapsed time = 5.501810073852539
# [('Owl', 99.28494691848755), ('Owl', 98.1050431728363), ('Owl', 77.81829237937927)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/11.jpg
# 12.jpg  /  527
# Elapsed time = 5.484011888504028
# [('Owl', 99.23689365386963), ('Owl', 98.61146211624146)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/12.jpg
# 13.jpg  /  527
# Elapsed time = 5.578713893890381
# [('Owl', 99.43073391914368), ('Owl', 98.21273684501648)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/13.jpg
# 14.jpg  /  527
# Elapsed time = 5.454814910888672
# [('Owl', 99.48000907897949), ('Owl', 98.47708344459534), ('Owl', 75.86231827735901)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/14.jpg
# 15.jpg  /  527
# Elapsed time = 5.759200811386108
# [('Owl', 99.51194524765015), ('Owl', 98.74927997589111), ('Owl', 72.8989839553833)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/15.jpg
# 16.jpg  /  527
# Elapsed time = 5.627099514007568
# [('Owl', 99.31403994560242), ('Owl', 96.9739556312561)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/16.jpg
# 17.jpg  /  527
# Elapsed time = 5.5088300704956055
# [('Owl', 99.43134784698486), ('Owl', 98.45053553581238)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/17.jpg
# 18.jpg  /  527
# Elapsed time = 5.553407669067383
# [('Owl', 99.58211183547974), ('Owl', 96.25178575515747), ('Owl', 86.14217638969421)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/18.jpg
# 19.jpg  /  527
# Elapsed time = 5.5923027992248535
# [('Owl', 99.49443936347961), ('Owl', 98.13932776451111)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/19.jpg
# 20.jpg  /  527
# Elapsed time = 5.443508148193359
# [('Owl', 99.46001768112183), ('Owl', 99.38021898269653), ('Owl', 87.77197599411011)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/20.jpg
# 21.jpg  /  527
# Elapsed time = 5.667863130569458
# [('Owl', 99.48480129241943), ('Owl', 98.5347032546997), ('Owl', 88.3403480052948)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/21.jpg
# 22.jpg  /  527
# Elapsed time = 5.554757118225098
# [('Owl', 99.44039583206177), ('Owl', 99.07874464988708), ('Owl', 86.56584620475769)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/22.jpg
# 23.jpg  /  527
# Elapsed time = 5.52768611907959
# [('Owl', 99.38580393791199), ('Owl', 98.24880957603455), ('Owl', 92.08108186721802), ('Owl', 71.36407494544983)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/23.jpg
# 24.jpg  /  527
# Elapsed time = 5.501311540603638
# [('Owl', 99.36461448669434), ('Owl', 99.27204847335815), ('Owl', 90.21353125572205)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/24.jpg
# 25.jpg  /  527
# Elapsed time = 5.709666967391968
# [('Owl', 99.42118525505066), ('Owl', 98.24945330619812), ('Owl', 91.23173952102661)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/25.jpg
# 26.jpg  /  527
# Elapsed time = 5.689788103103638
# [('Owl', 99.45616126060486), ('Owl', 97.97149300575256), ('Owl', 83.93005728721619)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/26.jpg
# 27.jpg  /  527
# Elapsed time = 5.531540393829346
# [('Owl', 99.45446252822876), ('Owl', 96.41677141189575), ('Owl', 82.10646510124207)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/27.jpg
# 28.jpg  /  527
# Elapsed time = 5.372630596160889
# [('Owl', 99.23099279403687), ('Owl', 93.10460686683655), ('Owl', 83.0105185508728)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/28.jpg
# 29.jpg  /  527
# Elapsed time = 5.3087756633758545
# [('Owl', 99.42164421081543), ('Owl', 97.15699553489685), ('Owl', 88.30551505088806), ('Owl', 72.04575538635254)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/29.jpg
# 30.jpg  /  527
# Elapsed time = 5.4602720737457275
# [('Owl', 99.43550825119019), ('Owl', 96.69740200042725), ('Owl', 80.58741092681885)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/30.jpg
# 31.jpg  /  527
# Elapsed time = 5.450648784637451
# [('Owl', 99.31539297103882), ('Owl', 97.65207171440125), ('Owl', 86.03078722953796)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/31.jpg
# 32.jpg  /  527
# Elapsed time = 5.547589063644409
# [('Owl', 99.44188594818115), ('Owl', 96.11107110977173), ('Owl', 83.14749598503113)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/32.jpg
# 33.jpg  /  527
# Elapsed time = 5.538089036941528
# [('Owl', 99.20769929885864), ('Owl', 98.39445948600769), ('Owl', 81.69340491294861)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/33.jpg
# 34.jpg  /  527
# Elapsed time = 5.694066286087036
# [('Owl', 99.15480017662048), ('Owl', 97.63854742050171), ('Owl', 79.90002036094666)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/34.jpg
# 35.jpg  /  527
# Elapsed time = 5.520732641220093
# [('Owl', 99.05800223350525), ('Owl', 98.10128808021545), ('Owl', 79.41844463348389)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/35.jpg
# 36.jpg  /  527
# Elapsed time = 5.369822978973389
# [('Owl', 99.15967583656311), ('Owl', 98.56789708137512), ('Owl', 79.83691692352295)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/36.jpg
# 37.jpg  /  527
# Elapsed time = 5.546421051025391
# [('Owl', 98.99296164512634), ('Owl', 98.79915118217468), ('Owl', 82.02947974205017)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/37.jpg
# 38.jpg  /  527
# Elapsed time = 5.6606128215789795
# [('Owl', 98.72849583625793), ('Owl', 98.69691133499146), ('Owl', 75.47052502632141)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/38.jpg
# 39.jpg  /  527
# Elapsed time = 5.528363227844238
# [('Owl', 97.98239469528198), ('Owl', 97.93857932090759), ('Owl', 82.32951164245605)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/39.jpg
# 40.jpg  /  527
# Elapsed time = 5.55095100402832
# [('Owl', 98.23328852653503), ('Owl', 98.1695294380188), ('Owl', 78.34624648094177)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/40.jpg
# 41.jpg  /  527
# Elapsed time = 5.741928577423096
# [('Owl', 98.35615754127502), ('Owl', 97.69635796546936), ('Owl', 74.33658838272095)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/41.jpg
# 42.jpg  /  527
# Elapsed time = 5.6288111209869385
# [('Owl', 98.67585301399231), ('Owl', 97.17046022415161)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/42.jpg
# 43.jpg  /  527
# Elapsed time = 5.456661224365234
# [('Owl', 98.85804057121277), ('Owl', 98.46081137657166)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/43.jpg
# 44.jpg  /  527
# Elapsed time = 5.592997312545776
# [('Owl', 99.02029037475586), ('Owl', 97.80234694480896)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/44.jpg
# 45.jpg  /  527
# Elapsed time = 5.515902996063232
# [('Owl', 99.08559322357178), ('Owl', 98.46173524856567), ('Owl', 72.68190383911133)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/45.jpg
# 46.jpg  /  527
# Elapsed time = 5.553981781005859
# [('Owl', 99.16929602622986), ('Owl', 97.72363901138306), ('Owl', 72.00253009796143)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/46.jpg
# 47.jpg  /  527
# Elapsed time = 5.521844148635864
# [('Owl', 99.03557300567627), ('Owl', 97.3997712135315), ('Owl', 75.60256123542786)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/47.jpg
# 48.jpg  /  527
# Elapsed time = 5.531701326370239
# [('Owl', 99.24490451812744), ('Owl', 99.12443161010742), ('Owl', 70.16719579696655)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/48.jpg
# 49.jpg  /  527
# Elapsed time = 5.627670049667358
# [('Owl', 99.24813508987427), ('Owl', 97.8626012802124), ('Owl', 74.12803769111633)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/49.jpg
# 50.jpg  /  527
# Elapsed time = 5.4660656452178955
# [('Owl', 99.24013614654541), ('Owl', 98.61449003219604), ('Owl', 70.54696679115295)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/50.jpg
# 51.jpg  /  527
# Elapsed time = 5.487637758255005
# [('Owl', 99.11207556724548), ('Owl', 98.40494394302368), ('Owl', 71.97744250297546)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/51.jpg
# 52.jpg  /  527
# Elapsed time = 5.630192756652832
# [('Owl', 99.08016324043274), ('Owl', 97.43810296058655), ('Owl', 75.98274946212769)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/52.jpg
# 53.jpg  /  527
# Elapsed time = 5.617928743362427
# [('Owl', 99.15573596954346), ('Owl', 99.0871250629425), ('Owl', 80.12909293174744)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/53.jpg
# 54.jpg  /  527
# Elapsed time = 5.413953065872192
# [('Owl', 99.18367266654968), ('Owl', 98.82115721702576), ('Owl', 83.16243290901184)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/54.jpg
# 55.jpg  /  527
# Elapsed time = 5.591128587722778
# [('Owl', 99.28165674209595), ('Owl', 97.67709970474243), ('Owl', 75.00279545783997)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/55.jpg
# 56.jpg  /  527
# Elapsed time = 5.724791765213013
# [('Owl', 99.30869936943054), ('Owl', 96.86143398284912), ('Owl', 75.98894238471985)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/56.jpg
# 57.jpg  /  527
# Elapsed time = 5.510766983032227
# [('Owl', 99.33880567550659), ('Owl', 98.5205590724945), ('Owl', 78.66314649581909)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/57.jpg
# 58.jpg  /  527
# Elapsed time = 5.634786605834961
# [('Owl', 99.35064315795898), ('Owl', 95.11862993240356), ('Owl', 77.89546251296997)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/58.jpg
# 59.jpg  /  527
# Elapsed time = 5.438664436340332
# [('Owl', 99.36571717262268), ('Owl', 97.07689881324768)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/59.jpg
# 60.jpg  /  527
# Elapsed time = 5.606063365936279
# [('Owl', 99.37614798545837), ('Owl', 97.54001498222351)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/60.jpg
# 61.jpg  /  527
# Elapsed time = 5.739878177642822
# [('Owl', 99.17653203010559), ('Owl', 97.32956886291504), ('Owl', 86.39126420021057)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/61.jpg
# 62.jpg  /  527
# Elapsed time = 5.575901985168457
# [('Owl', 99.18136596679688), ('Owl', 97.10859060287476), ('Owl', 85.1078987121582)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/62.jpg
# 63.jpg  /  527
# Elapsed time = 5.760557413101196
# [('Owl', 99.18786287307739), ('Owl', 97.93775677680969), ('Owl', 84.89037752151489)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/63.jpg
# 64.jpg  /  527
# Elapsed time = 5.687394618988037
# [('Owl', 99.23072457313538), ('Owl', 97.06158638000488), ('Owl', 88.14981579780579)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/64.jpg
# 65.jpg  /  527
# Elapsed time = 5.746230840682983
# [('Owl', 99.14330244064331), ('Owl', 98.89158010482788), ('Owl', 87.60238289833069)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/65.jpg
# 66.jpg  /  527
# Elapsed time = 5.710571527481079
# [('Owl', 99.3008017539978), ('Owl', 98.30295443534851), ('Owl', 82.68134593963623)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/66.jpg
# 67.jpg  /  527
# Elapsed time = 5.706391096115112
# [('Owl', 99.11483526229858), ('Owl', 98.52452874183655), ('Owl', 70.0321614742279)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/67.jpg
# 68.jpg  /  527
# Elapsed time = 5.860871315002441
# [('Owl', 99.14270639419556), ('Owl', 98.81276488304138)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/68.jpg
# 69.jpg  /  527
# Elapsed time = 5.6809775829315186
# [('Owl', 99.25832748413086), ('Owl', 99.1292655467987), ('Owl', 78.75447273254395)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/69.jpg
# 70.jpg  /  527
# Elapsed time = 5.615554094314575
# [('Owl', 99.21653270721436), ('Owl', 99.06895160675049), ('Owl', 75.94403624534607)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/70.jpg
# 71.jpg  /  527
# Elapsed time = 5.504063606262207
# [('Owl', 98.96259903907776), ('Owl', 98.5150158405304), ('Owl', 77.12491154670715)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/71.jpg
# 72.jpg  /  527
# Elapsed time = 5.7657811641693115
# [('Owl', 99.02363419532776), ('Owl', 98.94994497299194), ('Owl', 80.96511960029602)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/72.jpg
# 73.jpg  /  527
# Elapsed time = 5.515374660491943
# [('Owl', 99.09334182739258), ('Owl', 98.99829030036926), ('Owl', 81.56015276908875)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/73.jpg
# 74.jpg  /  527
# Elapsed time = 5.460033416748047
# [('Owl', 99.25224184989929), ('Owl', 99.23498034477234), ('Owl', 85.93195676803589)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/74.jpg
# 75.jpg  /  527
# Elapsed time = 5.704408168792725
# [('Owl', 99.31259155273438), ('Owl', 99.19615387916565)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/75.jpg
# 76.jpg  /  527
# Elapsed time = 5.651649236679077
# [('Owl', 99.18881058692932), ('Owl', 99.16165471076965)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/76.jpg
# 77.jpg  /  527
# Elapsed time = 5.660508871078491
# [('Owl', 99.42875504493713), ('Owl', 99.08736944198608)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/77.jpg
# 78.jpg  /  527
# Elapsed time = 5.43484091758728
# [('Owl', 99.22211766242981), ('Owl', 98.62956404685974)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/78.jpg
# 79.jpg  /  527
# Elapsed time = 5.771551132202148
# [('Owl', 99.1561233997345), ('Owl', 99.00235533714294), ('Owl', 79.17325496673584)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/79.jpg
# 80.jpg  /  527
# Elapsed time = 5.517574310302734
# [('Owl', 99.18413162231445), ('Owl', 98.74186515808105), ('Owl', 81.95305466651917)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/80.jpg
# 81.jpg  /  527
# Elapsed time = 5.544168710708618
# [('Owl', 99.35728311538696), ('Owl', 99.03276562690735)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/81.jpg
# 82.jpg  /  527
# Elapsed time = 5.806154489517212
# [('Owl', 99.56049919128418), ('Owl', 99.02021288871765), ('Owl', 76.31479501724243)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/82.jpg
# 83.jpg  /  527
# Elapsed time = 5.5427000522613525
# [('Owl', 99.3354082107544), ('Owl', 98.9560604095459), ('Owl', 89.58393931388855)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/83.jpg
# 84.jpg  /  527
# Elapsed time = 5.489241361618042
# [('Owl', 98.94891381263733), ('Owl', 98.90605211257935), ('Owl', 78.46395373344421)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/84.jpg
# 85.jpg  /  527
# Elapsed time = 5.592358350753784
# [('Owl', 99.04848337173462), ('Owl', 98.84390234947205), ('Owl', 82.28906989097595)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/85.jpg
# 86.jpg  /  527
# Elapsed time = 5.499596834182739
# [('Owl', 99.11649823188782), ('Owl', 99.08639788627625), ('Owl', 86.96087598800659)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/86.jpg
# 87.jpg  /  527
# Elapsed time = 5.609212636947632
# [('Owl', 99.08243417739868), ('Owl', 99.06696081161499), ('Owl', 85.67554354667664)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/87.jpg
# 88.jpg  /  527
# Elapsed time = 5.620140790939331
# [('Owl', 99.2488145828247), ('Owl', 99.01789426803589), ('Owl', 80.84419369697571)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/88.jpg
# 89.jpg  /  527
# Elapsed time = 5.775223970413208
# [('Owl', 99.17080998420715), ('Owl', 97.88697361946106), ('Owl', 74.44226145744324)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/89.jpg
# 90.jpg  /  527
# Elapsed time = 5.556700229644775
# [('Owl', 99.26409125328064), ('Owl', 99.17877316474915), ('Owl', 81.41769170761108)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/90.jpg
# 91.jpg  /  527
# Elapsed time = 5.828069448471069
# [('Owl', 99.29500818252563), ('Owl', 98.84187579154968), ('Owl', 85.96386909484863)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/91.jpg
# 92.jpg  /  527
# Elapsed time = 5.4987382888793945
# [('Owl', 99.34451580047607), ('Owl', 97.97877669334412), ('Owl', 86.9805097579956)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/92.jpg
# 93.jpg  /  527
# Elapsed time = 5.600248575210571
# [('Owl', 99.27782416343689), ('Owl', 98.00251722335815), ('Owl', 85.8799397945404)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/93.jpg
# 94.jpg  /  527
# Elapsed time = 5.685201168060303
# [('Owl', 99.3450403213501), ('Owl', 98.40641021728516), ('Owl', 78.37274670600891)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/94.jpg
# 95.jpg  /  527
# Elapsed time = 5.706542253494263
# [('Owl', 99.32693839073181), ('Owl', 98.44157099723816)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/95.jpg
# 96.jpg  /  527
# Elapsed time = 5.704768180847168
# [('Owl', 99.36240911483765), ('Owl', 98.47530722618103)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/96.jpg
# 97.jpg  /  527
# Elapsed time = 5.607217788696289
# [('Owl', 99.19849038124084), ('Owl', 98.56787323951721)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/97.jpg
# 98.jpg  /  527
# Elapsed time = 5.592039346694946
# [('Owl', 99.29351210594177), ('Owl', 98.290354013443)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/98.jpg
# 99.jpg  /  527
# Elapsed time = 5.370948076248169
# [('Owl', 99.38387274742126), ('Owl', 98.8146185874939), ('Owl', 83.29098224639893)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/99.jpg
# 100.jpg  /  527
# Elapsed time = 5.785013914108276
# [('Owl', 99.34230446815491), ('Owl', 98.84823560714722), ('Owl', 77.61451601982117)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/100.jpg
# 101.jpg  /  527
# Elapsed time = 5.829902410507202
# [('Owl', 99.30167198181152), ('Owl', 98.76686930656433), ('Owl', 79.45817708969116)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/101.jpg
# 102.jpg  /  527
# Elapsed time = 5.578479528427124
# [('Owl', 99.31239485740662), ('Owl', 98.42543601989746), ('Owl', 81.64824843406677)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/102.jpg
# 103.jpg  /  527
# Elapsed time = 5.621636152267456
# [('Owl', 99.3470311164856), ('Owl', 98.38728308677673), ('Owl', 80.47508597373962)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/103.jpg
# 104.jpg  /  527
# Elapsed time = 5.49940299987793
# [('Owl', 99.3054449558258), ('Owl', 98.45675230026245), ('Owl', 79.95046377182007)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/104.jpg
# 105.jpg  /  527
# Elapsed time = 5.606741189956665
# [('Owl', 99.2895781993866), ('Owl', 98.54363799095154), ('Owl', 83.56119394302368)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/105.jpg
# 106.jpg  /  527
# Elapsed time = 5.3537561893463135
# [('Owl', 99.31996464729309), ('Owl', 99.21872615814209), ('Owl', 82.23364353179932)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/106.jpg
# 107.jpg  /  527
# Elapsed time = 5.712036371231079
# [('Owl', 99.12458062171936), ('Owl', 98.40243458747864), ('Owl', 78.86290550231934)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/107.jpg
# 108.jpg  /  527
# Elapsed time = 5.424074172973633
# [('Owl', 99.18915033340454), ('Owl', 98.37107062339783), ('Owl', 79.25611138343811)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/108.jpg
# 109.jpg  /  527
# Elapsed time = 5.890280246734619
# [('Owl', 99.27050471305847), ('Owl', 97.79346585273743), ('Owl', 83.37926864624023)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/109.jpg
# 110.jpg  /  527
# Elapsed time = 5.587197780609131
# [('Owl', 99.2407500743866), ('Owl', 97.74174690246582), ('Owl', 84.74671840667725)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/110.jpg
# 111.jpg  /  527
# Elapsed time = 5.901194095611572
# [('Owl', 99.30971264839172), ('Owl', 99.16692972183228), ('Owl', 70.09691596031189)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/111.jpg
# 112.jpg  /  527
# Elapsed time = 5.574847936630249
# [('Owl', 99.307382106781), ('Owl', 99.07429814338684), ('Owl', 70.81810235977173)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/112.jpg
# 113.jpg  /  527
# Elapsed time = 5.733955144882202
# [('Owl', 99.24644231796265), ('Owl', 98.47908616065979), ('Owl', 82.024484872818)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/113.jpg
# 114.jpg  /  527
# Elapsed time = 5.572200536727905
# [('Owl', 99.2598295211792), ('Owl', 98.51052761077881), ('Owl', 83.89495015144348)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/114.jpg
# 115.jpg  /  527
# Elapsed time = 5.638021469116211
# [('Owl', 99.23580288887024), ('Owl', 99.23014640808105), ('Owl', 92.52136945724487)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/115.jpg
# 116.jpg  /  527
# Elapsed time = 5.5887181758880615
# [('Owl', 99.2236077785492), ('Owl', 98.9148199558258), ('Owl', 91.83598160743713)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/116.jpg
# 117.jpg  /  527
# Elapsed time = 5.592741012573242
# [('Owl', 99.26239252090454), ('Owl', 97.93691039085388), ('Owl', 92.43993759155273)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/117.jpg
# 118.jpg  /  527
# Elapsed time = 5.526795387268066
# [('Owl', 99.20897483825684), ('Owl', 98.83041381835938), ('Owl', 93.74494552612305)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/118.jpg
# 119.jpg  /  527
# Elapsed time = 5.555586576461792
# [('Owl', 99.2551326751709), ('Owl', 98.63203167915344), ('Owl', 92.54099726676941), ('Owl', 82.54234790802002)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/119.jpg
# 120.jpg  /  527
# Elapsed time = 5.813534736633301
# [('Owl', 99.25633072853088), ('Owl', 97.07351922988892), ('Owl', 92.3792839050293), ('Owl', 73.28602075576782)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/120.jpg
# 121.jpg  /  527
# Elapsed time = 5.484325885772705
# [('Owl', 99.2255687713623), ('Owl', 99.22080636024475), ('Owl', 91.7833685874939), ('Owl', 70.84679007530212)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/121.jpg
# 122.jpg  /  527
# Elapsed time = 5.601819753646851
# [('Owl', 99.33317303657532), ('Owl', 98.24895858764648), ('Owl', 91.694176197052)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/122.jpg
# 123.jpg  /  527
# Elapsed time = 5.775493621826172
# [('Owl', 99.10167455673218), ('Owl', 99.08881187438965), ('Owl', 79.70218658447266)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/123.jpg
# 124.jpg  /  527
# Elapsed time = 5.598424196243286
# [('Owl', 99.38123226165771), ('Owl', 99.26980137825012), ('Owl', 82.1090817451477)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/124.jpg
# 125.jpg  /  527
# Elapsed time = 5.531248331069946
# [('Owl', 99.2857575416565), ('Owl', 99.21396374702454), ('Owl', 79.76269125938416)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/125.jpg
# 126.jpg  /  527
# Elapsed time = 5.530348539352417
# [('Owl', 99.53266382217407), ('Owl', 99.30323362350464), ('Owl', 83.25221538543701)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/126.jpg
# 127.jpg  /  527
# Elapsed time = 5.393795728683472
# [('Owl', 99.63384866714478), ('Owl', 99.29636120796204), ('Owl', 82.09705948829651)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/127.jpg
# 128.jpg  /  527
# Elapsed time = 5.60521388053894
# [('Owl', 99.58587288856506), ('Owl', 99.34874773025513), ('Owl', 85.24478673934937)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/128.jpg
# 129.jpg  /  527
# Elapsed time = 5.591910362243652
# [('Owl', 99.59940910339355), ('Owl', 99.50809478759766), ('Owl', 84.08558964729309)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/129.jpg
# 130.jpg  /  527
# Elapsed time = 5.944742918014526
# [('Owl', 99.4804322719574), ('Owl', 99.40527081489563), ('Owl', 90.95094799995422)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/130.jpg
# 131.jpg  /  527
# Elapsed time = 5.490764379501343
# [('Owl', 99.39481019973755), ('Owl', 98.96388053894043), ('Owl', 74.63840246200562)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/131.jpg
# 132.jpg  /  527
# Elapsed time = 5.350713729858398
# [('Owl', 99.32966828346252), ('Owl', 99.10145401954651), ('Owl', 80.80856800079346)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/132.jpg
# 133.jpg  /  527
# Elapsed time = 5.808350563049316
# [('Owl', 99.09554123878479), ('Owl', 98.98777604103088), ('Owl', 81.51995539665222)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/133.jpg
# 134.jpg  /  527
# Elapsed time = 5.631495952606201
# [('Owl', 99.21265840530396), ('Owl', 98.69357943534851), ('Owl', 80.42477369308472)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/134.jpg
# 135.jpg  /  527
# Elapsed time = 5.572371244430542
# [('Owl', 99.04257655143738), ('Owl', 98.24864864349365), ('Owl', 77.43491530418396)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/135.jpg
# 136.jpg  /  527
# Elapsed time = 5.619390964508057
# [('Owl', 99.28211569786072), ('Owl', 97.47390151023865), ('Owl', 71.28617763519287)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/136.jpg
# 137.jpg  /  527
# Elapsed time = 5.6011643409729
# [('Owl', 99.29823875427246), ('Owl', 98.11282157897949), ('Owl', 77.29659080505371)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/137.jpg
# 138.jpg  /  527
# Elapsed time = 5.614518165588379
# [('Owl', 99.21557307243347), ('Owl', 99.15618300437927), ('Owl', 78.16416025161743)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/138.jpg
# 139.jpg  /  527
# Elapsed time = 5.9565041065216064
# [('Owl', 99.48537945747375), ('Owl', 99.08338189125061), ('Owl', 76.53262615203857)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/139.jpg
# 140.jpg  /  527
# Elapsed time = 5.861552476882935
# [('Owl', 99.41061735153198), ('Owl', 98.73980283737183), ('Owl', 79.59321737289429)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/140.jpg
# 141.jpg  /  527
# Elapsed time = 5.684006452560425
# [('Owl', 99.49443936347961), ('Owl', 98.59915375709534), ('Owl', 81.44749999046326)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/141.jpg
# 142.jpg  /  527
# Elapsed time = 5.519915580749512
# [('Owl', 99.42442774772644), ('Owl', 98.96295666694641), ('Owl', 80.87624907493591)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/142.jpg
# 143.jpg  /  527
# Elapsed time = 5.575669527053833
# [('Owl', 99.35053586959839), ('Owl', 99.0899920463562), ('Owl', 89.52221870422363)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/143.jpg
# 144.jpg  /  527
# Elapsed time = 5.540807723999023
# [('Owl', 99.36313033103943), ('Owl', 99.30508136749268), ('Owl', 84.58831310272217)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/144.jpg
# 145.jpg  /  527
# Elapsed time = 5.410531282424927
# [('Owl', 99.44304823875427), ('Owl', 99.38103556632996), ('Owl', 83.94641876220703)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/145.jpg
# 146.jpg  /  527
# Elapsed time = 5.656612873077393
# [('Owl', 99.46605563163757), ('Owl', 99.33111667633057), ('Owl', 89.93979096412659)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/146.jpg
# 147.jpg  /  527
# Elapsed time = 5.67493200302124
# [('Owl', 99.58040118217468), ('Owl', 99.50409531593323), ('Owl', 84.29359793663025)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/147.jpg
# 148.jpg  /  527
# Elapsed time = 5.53710675239563
# [('Owl', 99.48368072509766), ('Owl', 99.37459230422974), ('Owl', 89.14592266082764)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/148.jpg
# 149.jpg  /  527
# Elapsed time = 5.812417268753052
# [('Owl', 99.45451021194458), ('Owl', 99.32725429534912), ('Owl', 89.69734907150269)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/149.jpg
# 150.jpg  /  527
# Elapsed time = 5.613570690155029
# [('Owl', 99.46738481521606), ('Owl', 99.41487312316895), ('Owl', 83.51613879203796)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/150.jpg
# 151.jpg  /  527
# Elapsed time = 5.50516414642334
# [('Owl', 99.40350651741028), ('Owl', 99.3901014328003), ('Owl', 77.78117060661316)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/151.jpg
# 152.jpg  /  527
# Elapsed time = 5.613585710525513
# [('Owl', 99.41585063934326), ('Owl', 99.41537976264954), ('Owl', 78.21345925331116)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/152.jpg
# 153.jpg  /  527
# Elapsed time = 5.517306566238403
# [('Owl', 99.44984316825867), ('Owl', 99.40978288650513), ('Owl', 80.16189336776733)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/153.jpg
# 154.jpg  /  527
# Elapsed time = 5.569385528564453
# [('Owl', 99.48551654815674), ('Owl', 99.46680068969727), ('Owl', 80.64407706260681)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/154.jpg
# 155.jpg  /  527
# Elapsed time = 5.64920449256897
# [('Owl', 99.67081546783447), ('Owl', 99.54524636268616), ('Owl', 85.38585901260376)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/155.jpg
# 156.jpg  /  527
# Elapsed time = 5.787987232208252
# [('Owl', 99.61620569229126), ('Owl', 99.50547218322754), ('Owl', 82.13698863983154)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/156.jpg
# 157.jpg  /  527
# Elapsed time = 5.467057228088379
# [('Owl', 99.52839016914368), ('Owl', 99.51663017272949), ('Owl', 83.99311304092407)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/157.jpg
# 158.jpg  /  527
# Elapsed time = 5.805766820907593
# [('Owl', 99.71500039100647), ('Owl', 99.4595468044281), ('Owl', 84.49627757072449)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/158.jpg
# 159.jpg  /  527
# Elapsed time = 5.49640679359436
# [('Owl', 99.55392479896545), ('Owl', 99.45160746574402), ('Owl', 83.6357593536377)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/159.jpg
# 160.jpg  /  527
# Elapsed time = 5.614070653915405
# [('Owl', 99.44227337837219), ('Owl', 99.42856431007385), ('Owl', 87.33782172203064)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/160.jpg
# 161.jpg  /  527
# Elapsed time = 5.553256273269653
# [('Owl', 99.65393543243408), ('Owl', 99.42967295646667), ('Owl', 89.59201574325562)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/161.jpg
# 162.jpg  /  527
# Elapsed time = 5.506840467453003
# [('Owl', 99.58437085151672), ('Owl', 99.432373046875), ('Owl', 89.99778628349304)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/162.jpg
# 163.jpg  /  527
# Elapsed time = 5.510398864746094
# [('Owl', 99.5225191116333), ('Owl', 99.28241968154907), ('Owl', 81.64373636245728)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/163.jpg
# 164.jpg  /  527
# Elapsed time = 5.493278980255127
# [('Owl', 99.52800273895264), ('Owl', 99.0693747997284), ('Owl', 83.69914889335632)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/164.jpg
# 165.jpg  /  527
# Elapsed time = 5.102960824966431
# [('Owl', 99.52685236930847), ('Owl', 99.51867461204529), ('Owl', 92.55131483078003)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/165.jpg
# 166.jpg  /  527
# Elapsed time = 5.38871431350708
# [('Owl', 99.54668283462524), ('Owl', 99.36791062355042), ('Owl', 83.49113464355469)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/166.jpg
# 167.jpg  /  527
# Elapsed time = 5.427653551101685
# [('Owl', 99.52902793884277), ('Owl', 99.46699738502502), ('Owl', 81.70369267463684)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/167.jpg
# 168.jpg  /  527
# Elapsed time = 5.502447128295898
# [('Owl', 99.52815175056458), ('Owl', 99.4261384010315)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/168.jpg
# 169.jpg  /  527
# Elapsed time = 5.215880870819092
# [('Owl', 99.53159093856812), ('Owl', 99.52627420425415), ('Owl', 82.94363021850586)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/169.jpg
# 170.jpg  /  527
# Elapsed time = 5.268378257751465
# [('Owl', 99.6399998664856), ('Owl', 99.5135486125946), ('Owl', 82.14755058288574)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/170.jpg
# 171.jpg  /  527
# Elapsed time = 5.144885301589966
# [('Owl', 99.65803027153015), ('Owl', 99.48497414588928)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/171.jpg
# 172.jpg  /  527
# Elapsed time = 5.240675687789917
# [('Owl', 99.76826906204224), ('Owl', 99.46407079696655), ('Owl', 81.09461665153503)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/172.jpg
# 173.jpg  /  527
# Elapsed time = 5.237083673477173
# [('Owl', 99.66592788696289), ('Owl', 99.46750402450562), ('Owl', 83.36368203163147)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/173.jpg
# 174.jpg  /  527
# Elapsed time = 5.550631761550903
# [('Owl', 99.49341416358948), ('Owl', 99.41927790641785), ('Owl', 83.79778265953064)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/174.jpg
# 175.jpg  /  527
# Elapsed time = 5.409865140914917
# [('Owl', 99.66660141944885), ('Owl', 99.54892992973328), ('Owl', 83.27476978302002)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/175.jpg
# 176.jpg  /  527
# Elapsed time = 5.46218466758728
# [('Owl', 99.49479103088379), ('Owl', 99.15040135383606), ('Owl', 85.82581281661987)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/176.jpg
# 177.jpg  /  527
# Elapsed time = 5.7502760887146
# [('Owl', 99.45058226585388), ('Owl', 98.97979497909546), ('Owl', 85.80225706100464)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/177.jpg
# 178.jpg  /  527
# Elapsed time = 5.45814847946167
# [('Owl', 99.4694173336029), ('Owl', 99.36614036560059), ('Owl', 85.37458777427673)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/178.jpg
# 179.jpg  /  527
# Elapsed time = 5.2593536376953125
# [('Owl', 99.52774047851562), ('Owl', 98.99764657020569), ('Owl', 80.73657751083374)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/179.jpg
# 180.jpg  /  527
# Elapsed time = 5.688279151916504
# [('Owl', 99.49308037757874), ('Owl', 99.2191731929779), ('Owl', 89.34730887413025)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/180.jpg
# 181.jpg  /  527
# Elapsed time = 5.58287501335144
# [('Owl', 99.4989812374115), ('Owl', 98.73616695404053), ('Owl', 91.64298176765442)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/181.jpg
# 182.jpg  /  527
# Elapsed time = 5.439543724060059
# [('Owl', 99.52151775360107), ('Owl', 98.97446036338806), ('Owl', 90.993332862854)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/182.jpg
# 183.jpg  /  527
# Elapsed time = 5.5849690437316895
# [('Owl', 99.53368306159973), ('Owl', 99.15635585784912), ('Owl', 91.77471399307251)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/183.jpg
# 184.jpg  /  527
# Elapsed time = 5.326296329498291
# [('Owl', 99.55657124519348), ('Owl', 99.28414821624756), ('Owl', 91.50569438934326)]
# ...
# 467.jpg  /  527
# Elapsed time = 5.239691257476807
# [('Owl', 99.56973791122437), ('Owl', 98.27636480331421), ('Owl', 85.10295748710632)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/467.jpg
# 468.jpg  /  527
# Elapsed time = 5.296318531036377
# [('Owl', 99.39420819282532), ('Owl', 97.35313653945923), ('Owl', 80.26483058929443)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/468.jpg
# 469.jpg  /  527
# Elapsed time = 5.20589542388916
# [('Owl', 99.40981864929199), ('Owl', 98.4074592590332), ('Owl', 82.87231922149658)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/469.jpg
# 470.jpg  /  527
# Elapsed time = 5.478891849517822
# [('Owl', 99.1066038608551), ('Owl', 98.42766523361206), ('Owl', 90.49879312515259)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/470.jpg
# 471.jpg  /  527
# Elapsed time = 5.320542335510254
# [('Owl', 99.47758913040161), ('Owl', 98.48665595054626), ('Owl', 90.28995037078857)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/471.jpg
# 472.jpg  /  527
# Elapsed time = 5.320045232772827
# [('Owl', 99.51645135879517), ('Owl', 98.7058937549591), ('Owl', 90.78478813171387)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/472.jpg
# 473.jpg  /  527
# Elapsed time = 5.52018666267395
# [('Owl', 99.44398403167725), ('Owl', 99.00387525558472), ('Owl', 90.790456533432)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/473.jpg
# 474.jpg  /  527
# Elapsed time = 5.376337766647339
# [('Owl', 99.43751096725464), ('Owl', 99.33860898017883), ('Owl', 91.38628840446472)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/474.jpg
# 475.jpg  /  527
# Elapsed time = 5.377230167388916
# [('Owl', 99.52802658081055), ('Owl', 98.85651469230652), ('Owl', 86.53174638748169)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/475.jpg
# 476.jpg  /  527
# Elapsed time = 5.337987899780273
# [('Owl', 99.6297538280487), ('Owl', 98.48753809928894), ('Owl', 84.42884087562561)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/476.jpg
# 477.jpg  /  527
# Elapsed time = 5.30338716506958
# [('Owl', 99.55490827560425), ('Owl', 97.83101081848145), ('Owl', 86.35861277580261)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/477.jpg
# 478.jpg  /  527
# Elapsed time = 5.258761167526245
# [('Owl', 99.54209923744202), ('Owl', 99.15722608566284), ('Owl', 87.58031129837036)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/478.jpg
# 479.jpg  /  527
# Elapsed time = 5.339142799377441
# [('Owl', 99.56488013267517), ('Owl', 99.49280023574829), ('Owl', 87.1688961982727)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/479.jpg
# 480.jpg  /  527
# Elapsed time = 5.2904253005981445
# [('Owl', 99.58472847938538), ('Owl', 99.34750199317932), ('Owl', 87.42232322692871)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/480.jpg
# 481.jpg  /  527
# Elapsed time = 5.2498674392700195
# [('Owl', 99.64099526405334), ('Owl', 99.20281767845154), ('Owl', 84.54716205596924)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/481.jpg
# 482.jpg  /  527
# Elapsed time = 5.485394477844238
# [('Owl', 99.60333704948425), ('Owl', 99.53303337097168), ('Owl', 84.84470844268799)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/482.jpg
# 483.jpg  /  527
# Elapsed time = 5.361896753311157
# [('Owl', 99.38148260116577), ('Owl', 99.33794736862183)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/483.jpg
# 484.jpg  /  527
# Elapsed time = 5.257987976074219
# [('Owl', 99.51903820037842), ('Owl', 99.4988739490509), ('Owl', 83.41917395591736)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/484.jpg
# 485.jpg  /  527
# Elapsed time = 5.35161566734314
# [('Owl', 99.5375394821167), ('Owl', 99.5316743850708), ('Owl', 77.97232866287231)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/485.jpg
# 486.jpg  /  527
# Elapsed time = 5.429259777069092
# [('Owl', 99.516761302948), ('Owl', 99.45225715637207)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/486.jpg
# 487.jpg  /  527
# Elapsed time = 5.437934875488281
# [('Owl', 99.4771420955658), ('Owl', 99.23087358474731)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/487.jpg
# 488.jpg  /  527
# Elapsed time = 5.172484636306763
# [('Owl', 99.62286949157715), ('Owl', 99.40489530563354)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/488.jpg
# 489.jpg  /  527
# Elapsed time = 5.631055593490601
# [('Owl', 99.54835176467896), ('Owl', 99.37344193458557), ('Owl', 80.10093569755554)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/489.jpg
# 490.jpg  /  527
# Elapsed time = 5.550554275512695
# [('Owl', 99.45791959762573), ('Owl', 99.34402108192444), ('Owl', 81.02632761001587)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/490.jpg
# 491.jpg  /  527
# Elapsed time = 5.4833338260650635
# [('Owl', 99.52502250671387), ('Owl', 99.4820237159729), ('Owl', 92.08635091781616)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/491.jpg
# 492.jpg  /  527
# Elapsed time = 5.790244102478027
# [('Owl', 99.61242079734802), ('Owl', 99.45479035377502), ('Owl', 91.9417679309845)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/492.jpg
# 493.jpg  /  527
# Elapsed time = 5.5116212368011475
# [('Owl', 99.5526373386383), ('Owl', 99.3707537651062), ('Owl', 85.55847406387329)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/493.jpg
# 494.jpg  /  527
# Elapsed time = 5.450603723526001
# [('Owl', 99.49210286140442), ('Owl', 99.48655962944031), ('Owl', 85.96221208572388)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/494.jpg
# 495.jpg  /  527
# Elapsed time = 5.543532848358154
# [('Owl', 99.35029149055481), ('Owl', 99.125075340271), ('Owl', 86.57017350196838)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/495.jpg
# 496.jpg  /  527
# Elapsed time = 5.608412981033325
# [('Owl', 99.35997724533081), ('Owl', 99.17312264442444), ('Owl', 85.61985492706299)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/496.jpg
# 497.jpg  /  527
# Elapsed time = 5.479589939117432
# [('Owl', 99.31520223617554), ('Owl', 99.21460747718811), ('Owl', 84.5765233039856)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/497.jpg
# 498.jpg  /  527
# Elapsed time = 5.407699108123779
# [('Owl', 99.41272735595703), ('Owl', 99.20478463172913), ('Owl', 85.58032512664795)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/498.jpg
# 499.jpg  /  527
# Elapsed time = 5.305128335952759
# [('Owl', 99.46564435958862), ('Owl', 99.44936633110046), ('Owl', 82.46458768844604)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/499.jpg
# 500.jpg  /  527
# Elapsed time = 5.500454425811768
# [('Owl', 99.46689009666443), ('Owl', 99.43016767501831), ('Owl', 82.20628499984741)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/500.jpg
# 501.jpg  /  527
# Elapsed time = 5.448697566986084
# [('Owl', 99.53717589378357), ('Owl', 99.53351616859436), ('Owl', 76.38495564460754)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/501.jpg
# 502.jpg  /  527
# Elapsed time = 5.674110412597656
# [('Owl', 99.5703637599945), ('Owl', 99.46444034576416), ('Owl', 77.68932580947876)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/502.jpg
# 503.jpg  /  527
# Elapsed time = 5.304597616195679
# [('Owl', 99.48421120643616), ('Owl', 99.46066737174988), ('Owl', 79.57760691642761)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/503.jpg
# 504.jpg  /  527
# Elapsed time = 5.350833415985107
# [('Owl', 99.49179887771606), ('Owl', 99.45422410964966), ('Owl', 82.24225640296936)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/504.jpg
# 505.jpg  /  527
# Elapsed time = 5.217315435409546
# [('Owl', 99.4748055934906), ('Owl', 99.41586256027222), ('Owl', 80.37832379341125)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/505.jpg
# 506.jpg  /  527
# Elapsed time = 5.2667460441589355
# [('Owl', 99.56134557723999), ('Owl', 99.3876039981842), ('Owl', 79.72134351730347)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/506.jpg
# 507.jpg  /  527
# Elapsed time = 5.3945910930633545
# [('Owl', 99.39007759094238), ('Owl', 99.20628666877747), ('Owl', 80.63332438468933)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/507.jpg
# 508.jpg  /  527
# Elapsed time = 5.42423677444458
# [('Owl', 99.53038692474365), ('Owl', 99.44325089454651), ('Owl', 81.01944327354431)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/508.jpg
# 509.jpg  /  527
# Elapsed time = 5.384904384613037
# [('Owl', 99.37485456466675), ('Owl', 99.21743869781494), ('Owl', 77.62756943702698)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/509.jpg
# 510.jpg  /  527
# Elapsed time = 5.277914524078369
# [('Owl', 99.37157034873962), ('Owl', 99.3331253528595), ('Owl', 81.94528222084045)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/510.jpg
# 511.jpg  /  527
# Elapsed time = 5.841456890106201
# [('Owl', 99.3016004562378), ('Owl', 98.09918999671936), ('Owl', 76.28183364868164), ('Owl', 75.45077204704285)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/511.jpg
# 512.jpg  /  527
# Elapsed time = 5.545573949813843
# [('Owl', 99.42424893379211), ('Owl', 99.34694766998291), ('Owl', 79.85491752624512), ('Owl', 79.57967519760132)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/512.jpg
# 513.jpg  /  527
# Elapsed time = 5.563742399215698
# [('Owl', 99.57499504089355), ('Owl', 99.35852885246277), ('Owl', 80.98188042640686)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/513.jpg
# 514.jpg  /  527
# Elapsed time = 5.511908531188965
# [('Owl', 99.37455654144287), ('Owl', 99.3368923664093)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/514.jpg
# 515.jpg  /  527
# Elapsed time = 5.5533483028411865
# [('Owl', 99.3913471698761), ('Owl', 99.34529066085815)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/515.jpg
# 516.jpg  /  527
# Elapsed time = 5.508065462112427
# [('Owl', 99.52385425567627), ('Owl', 99.39595460891724)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/516.jpg
# 517.jpg  /  527
# Elapsed time = 5.491963148117065
# [('Owl', 99.4996428489685), ('Owl', 99.41124320030212)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/517.jpg
# 518.jpg  /  527
# Elapsed time = 5.463441371917725
# [('Owl', 99.48910474777222), ('Owl', 99.42023158073425)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/518.jpg
# 519.jpg  /  527
# Elapsed time = 5.438627243041992
# [('Owl', 99.50919151306152), ('Owl', 99.39534068107605), ('Owl', 77.93023586273193)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/519.jpg
# 520.jpg  /  527
# Elapsed time = 5.324859142303467
# [('Owl', 99.4624674320221), ('Owl', 99.36959147453308), ('Owl', 76.83802247047424)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/520.jpg
# 521.jpg  /  527
# Elapsed time = 5.4044413566589355
# [('Owl', 99.4433581829071), ('Owl', 99.29648637771606), ('Owl', 75.16568899154663)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/521.jpg
# 522.jpg  /  527
# Elapsed time = 5.2393505573272705
# [('Owl', 99.43386912345886), ('Owl', 99.33485388755798), ('Owl', 77.13053822517395)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/522.jpg
# 523.jpg  /  527
# Elapsed time = 5.285820722579956
# [('Owl', 99.42892789840698), ('Owl', 99.36402440071106), ('Owl', 83.59292149543762)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/523.jpg
# 524.jpg  /  527
# Elapsed time = 5.244484186172485
# [('Owl', 99.4288444519043), ('Owl', 99.37593936920166), ('Owl', 79.51502799987793)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/524.jpg
# 525.jpg  /  527
# Elapsed time = 5.325607061386108
# [('Owl', 99.42007064819336), ('Owl', 99.38983917236328), ('Owl', 84.90184545516968)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/525.jpg
# 526.jpg  /  527
# Elapsed time = 5.251388311386108
# [('Owl', 99.44209456443787), ('Owl', 99.40235018730164), ('Owl', 85.56490540504456)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/526.jpg
# 527.jpg  /  527
# Elapsed time = 5.1685075759887695
# [('Owl', 99.51865077018738), ('Owl', 99.42903518676758), ('Owl', 84.52093601226807)]
# El archivo fue escrito en :{0} /content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred/527.jpg

# %% [markdown]
# **CREACION DEL VIDEO CON LAS IMAGENES PREDICHAS QUE SE GUARDARON**

# %% [markdown]
# EL VIDEO SE GUARDA EN LA MISMA CARPETA DE LAS IMAGENES PREDICHAS

# %%
#CREACION DEL VIDEO:
from cv2 import VideoWriter, VideoWriter_fourcc, imread,resize
import glob
images = list(glob.iglob(os.path.join('/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred','*.jpg')))
images = sorted(images,key=lambda x:float(os.path.split(x)[1][:-3]))
video_output = os.path.join('/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video_pred','video_proce.mp4')
fourcc =VideoWriter_fourcc(*'FMP4')
vid =None
size= None
is_color = True
for image in images:
  img = imread(image)
  if vid is None:
    if size is None:
      size = img.shape[1], img.shape[0]
    vid = VideoWriter(video_output, fourcc, float(30), size, is_color)
  if size[0] != img.shape[1] and size[1] != img.shape[0]:
    img = resize(img,size)
  vid.write(img)
vid.release()

# %% [markdown]
# **ELIMINANDO CARPETA DONDE SE GUARDARON LAS IMAGENES DEL VIDEO INICIALMENTE, SE BORRAN PORQUE YA TENEMOS LAS IMAGENES PREDICHAS**

# %%
# !rm -r '/content/drive/MyDrive/Colab Notebooks/VISION COMPUTACIONAL/LABORATORIO_2/images_video'
